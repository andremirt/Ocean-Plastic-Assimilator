# %% [markdown]
# # Running the experiments of the paper

# %% [markdown]
# ## 1. Run the assimilator double gyre experiments on double gyre files

# %%
# Download the data, if necessary

import wget
from pathlib import Path

files_to_download = ["parts_double_gyre_ref_eps_0.25_A_0.1175_as_2.nc", "parts_double_gyre_ref_eps_0.25_A_0.105_as_2.nc",
"parts_double_gyre_ref_eps_0.25_A_0.11_as_2.nc",
"parts_double_gyre_ref_eps_0.25_A_0.125_as_2.nc",
"parts_double_gyre_ref_eps_0.25_A_0.1_as_2.nc",
"parts_double_gyre_ref_eps_0.35_A_0.1_as_2.nc",
"parts_double_gyre_ref_eps_0.3_A_0.1_as_2.nc",
"parts_double_gyre_ref_eps_0.4_A_0.1_as_2.nc",
"parts_double_gyre_ref_eps_0.5_A_0.1_as_2.nc",
"parts_double_gyre_ref_eps_0_A_0.1_as_2.nc",
"parts_double_gyre_ref_eps_1_A_0.1_as_2.nc",
"parts_double_gyre_standard_as_3.nc"]

Path("data/").mkdir(exist_ok=True)
for file_to_download in files_to_download:
  if not Path(f"data/{file_to_download}").exists():
    print(f"Downloading {file_to_download}...")
    wget.download(f"https://zenodo.org/record/4426130/files/{file_to_download}", f"data/{file_to_download}")

print("All files required for experiment have been downloaded")

# %%
# %%time
from src.run_assimilator import run_assimilator

# Change the following parameters to reproduce the different experimental results
# Changing A and epsilon will require to have downloaded the corresponding files.
# If you are trying values of A and epsilon that do not have a corresponding dispersion file, you will have to generate it with the double gyre code

mu = 2
A = 0.1
epsilon = 0.25
sigma_rel = 0.01
OBSERVATION_LOCATIONS = [(12, 4), (55, 27)]

if __name__ == "__main__":
    run_assimilator(
        particles_dataset_path="data/parts_double_gyre_standard_as_3.nc",
        observations_type="from_simulation",
        observations_source_path=f"data/parts_double_gyre_ref_eps_{epsilon}_A_{A}_as_2.nc",
        simulation_name=f"mu_{mu}_A_{A}_eps_{epsilon}_sigma_rel_{sigma_rel}_obspoints_{OBSERVATION_LOCATIONS}",
        assimilation_domain_coords=(195, 20, 225, 40),
        assimilation_grid_size=(60, 40),
        size_ensemble=10,
        initial_ensemble_spread=0.05,
        t_start=0,
        t_end=2000,
        observations_error_percent=sigma_rel,
        observation_locations=OBSERVATION_LOCATIONS,
        initial_mass_multiplicator=mu,
    )
# Out:
# Successfully created data/data_mu_2_A_0.1_eps_0.25_sigma_rel_0.01_obspoints_[(12, 4), (55, 27)]/
# Successfully created outputs/output_mu_2_A_0.1_eps_0.25_sigma_rel_0.01_obspoints_[(12, 4), (55, 27)]/
# Start iterating
# =================================================
# Start iteration 1 / 2000
# =================================================
# Start iteration 2 / 2000
# =================================================
# Start iteration 3 / 2000
# =================================================
# Start iteration 4 / 2000
# =================================================
# Start iteration 5 / 2000
# =================================================
# Start iteration 6 / 2000
# =================================================
# Start iteration 7 / 2000
# =================================================
# Start iteration 8 / 2000
# =================================================
# Start iteration 9 / 2000
# =================================================
# Start iteration 10 / 2000
# =================================================
# Start iteration 11 / 2000
# =================================================
# Start iteration 12 / 2000
# =================================================
# Start iteration 13 / 2000
# =================================================
# Start iteration 14 / 2000
# =================================================
# Start iteration 15 / 2000
# =================================================
# Start iteration 16 / 2000
# =================================================
# Start iteration 17 / 2000
# =================================================
# Start iteration 18 / 2000
# =================================================
# Start iteration 19 / 2000
# =================================================
# Start iteration 20 / 2000
# =================================================
# Start iteration 21 / 2000
# =================================================
# Start iteration 22 / 2000
# =================================================
# Start iteration 23 / 2000
# =================================================
# Start iteration 24 / 2000
# =================================================
# Start iteration 25 / 2000
# =================================================
# Start iteration 26 / 2000
# =================================================
# Start iteration 27 / 2000
# =================================================
# Start iteration 28 / 2000
# =================================================
# Start iteration 29 / 2000
# =================================================
# Start iteration 30 / 2000
# =================================================
# Start iteration 31 / 2000
# =================================================
# Start iteration 32 / 2000
# =================================================
# Start iteration 33 / 2000
# =================================================
# Start iteration 34 / 2000
# =================================================
# Start iteration 35 / 2000
# =================================================
# Start iteration 36 / 2000
# =================================================
# Start iteration 37 / 2000
# =================================================
# Start iteration 38 / 2000
# =================================================
# Start iteration 39 / 2000
# =================================================
# Start iteration 40 / 2000
# =================================================
# Start iteration 41 / 2000
# =================================================
# Start iteration 42 / 2000
# =================================================
# Start iteration 43 / 2000
# =================================================
# Start iteration 44 / 2000
# =================================================
# Start iteration 45 / 2000
# =================================================
# Start iteration 46 / 2000
# =================================================
# Start iteration 47 / 2000
# =================================================
# Start iteration 48 / 2000
# =================================================
# Start iteration 49 / 2000
# =================================================
# Start iteration 50 / 2000
# =================================================
# Start iteration 51 / 2000
# =================================================
# Start iteration 52 / 2000
# =================================================
# Start iteration 53 / 2000
# =================================================
# Start iteration 54 / 2000
# =================================================
# Start iteration 55 / 2000
# =================================================
# Start iteration 56 / 2000
# =================================================
# Start iteration 57 / 2000
# =================================================
# Start iteration 58 / 2000
# =================================================
# Start iteration 59 / 2000
# =================================================
# Start iteration 60 / 2000
# =================================================
# Start iteration 61 / 2000
# =================================================
# Start iteration 62 / 2000
# =================================================
# Start iteration 63 / 2000
# =================================================
# Start iteration 64 / 2000
# =================================================
# Start iteration 65 / 2000
# =================================================
# Start iteration 66 / 2000
# =================================================
# Start iteration 67 / 2000
# =================================================
# Start iteration 68 / 2000
# =================================================
# Start iteration 69 / 2000
# =================================================
# Start iteration 70 / 2000
# =================================================
# Start iteration 71 / 2000
# =================================================
# Start iteration 72 / 2000
# =================================================
# Start iteration 73 / 2000
# =================================================
# Start iteration 74 / 2000
# =================================================
# Start iteration 75 / 2000
# =================================================
# Start iteration 76 / 2000
# =================================================
# Start iteration 77 / 2000
# =================================================
# Start iteration 78 / 2000
# =================================================
# Start iteration 79 / 2000
# =================================================
# Start iteration 80 / 2000
# =================================================
# Start iteration 81 / 2000
# =================================================
# Start iteration 82 / 2000
# =================================================
# Start iteration 83 / 2000
# =================================================
# Start iteration 84 / 2000
# =================================================
# Start iteration 85 / 2000
# =================================================
# Start iteration 86 / 2000
# =================================================
# Start iteration 87 / 2000
# =================================================
# Start iteration 88 / 2000
# =================================================
# Start iteration 89 / 2000
# =================================================
# Start iteration 90 / 2000
# =================================================
# Start iteration 91 / 2000
# =================================================
# Start iteration 92 / 2000
# =================================================
# Start iteration 93 / 2000
# =================================================
# Start iteration 94 / 2000
# =================================================
# Start iteration 95 / 2000
# =================================================
# Start iteration 96 / 2000
# =================================================
# Start iteration 97 / 2000
# =================================================
# Start iteration 98 / 2000
# =================================================
# Start iteration 99 / 2000
# =================================================
# Start iteration 100 / 2000
# =================================================
# Start iteration 101 / 2000
# =================================================
# Start iteration 102 / 2000
# =================================================
# Start iteration 103 / 2000
# =================================================
# Start iteration 104 / 2000
# =================================================
# Start iteration 105 / 2000
# =================================================
# Start iteration 106 / 2000
# =================================================
# Start iteration 107 / 2000
# =================================================
# Start iteration 108 / 2000
# =================================================
# Start iteration 109 / 2000
# =================================================
# Start iteration 110 / 2000
# =================================================
# Start iteration 111 / 2000
# =================================================
# Start iteration 112 / 2000
# =================================================
# Start iteration 113 / 2000
# =================================================
# Start iteration 114 / 2000
# =================================================
# Start iteration 115 / 2000
# =================================================
# Start iteration 116 / 2000
# =================================================
# Start iteration 117 / 2000
# =================================================
# Start iteration 118 / 2000
# =================================================
# Start iteration 119 / 2000
# =================================================
# Start iteration 120 / 2000
# =================================================
# Start iteration 121 / 2000
# =================================================
# Start iteration 122 / 2000
# =================================================
# Start iteration 123 / 2000
# =================================================
# Start iteration 124 / 2000
# =================================================
# Start iteration 125 / 2000
# =================================================
# Start iteration 126 / 2000
# =================================================
# Start iteration 127 / 2000
# =================================================
# Start iteration 128 / 2000
# =================================================
# Start iteration 129 / 2000
# =================================================
# Start iteration 130 / 2000
# =================================================
# Start iteration 131 / 2000
# =================================================
# Start iteration 132 / 2000
# =================================================
# Start iteration 133 / 2000
# =================================================
# Start iteration 134 / 2000
# =================================================
# Start iteration 135 / 2000
# =================================================
# Start iteration 136 / 2000
# =================================================
# Start iteration 137 / 2000
# =================================================
# Start iteration 138 / 2000
# =================================================
# Start iteration 139 / 2000
# =================================================
# Start iteration 140 / 2000
# =================================================
# Start iteration 141 / 2000
# =================================================
# Start iteration 142 / 2000
# =================================================
# Start iteration 143 / 2000
# =================================================
# Start iteration 144 / 2000
# =================================================
# Start iteration 145 / 2000
# =================================================
# Start iteration 146 / 2000
# =================================================
# Start iteration 147 / 2000
# =================================================
# Start iteration 148 / 2000
# =================================================
# Start iteration 149 / 2000
# =================================================
# Start iteration 150 / 2000
# =================================================
# Start iteration 151 / 2000
# =================================================
# Start iteration 152 / 2000
# =================================================
# Start iteration 153 / 2000
# =================================================
# Start iteration 154 / 2000
# =================================================
# Start iteration 155 / 2000
# =================================================
# Start iteration 156 / 2000
# =================================================
# Start iteration 157 / 2000
# =================================================
# Start iteration 158 / 2000
# =================================================
# Start iteration 159 / 2000
# =================================================
# Start iteration 160 / 2000
# =================================================
# Start iteration 161 / 2000
# =================================================
# Start iteration 162 / 2000
# =================================================
# Start iteration 163 / 2000
# =================================================
# Start iteration 164 / 2000
# =================================================
# Start iteration 165 / 2000
# =================================================
# Start iteration 166 / 2000
# =================================================
# Start iteration 167 / 2000
# =================================================
# Start iteration 168 / 2000
# =================================================
# Start iteration 169 / 2000
# =================================================
# Start iteration 170 / 2000
# =================================================
# Start iteration 171 / 2000
# =================================================
# Start iteration 172 / 2000
# =================================================
# Start iteration 173 / 2000
# =================================================
# Start iteration 174 / 2000
# =================================================
# Start iteration 175 / 2000
# =================================================
# Start iteration 176 / 2000
# =================================================
# Start iteration 177 / 2000
# =================================================
# Start iteration 178 / 2000
# =================================================
# Start iteration 179 / 2000
# =================================================
# Start iteration 180 / 2000
# =================================================
# Start iteration 181 / 2000
# =================================================
# Start iteration 182 / 2000
# =================================================
# Start iteration 183 / 2000
# =================================================
# Start iteration 184 / 2000
# =================================================
# Start iteration 185 / 2000
# =================================================
# Start iteration 186 / 2000
# =================================================
# Start iteration 187 / 2000
# =================================================
# Start iteration 188 / 2000
# =================================================
# Start iteration 189 / 2000
# =================================================
# Start iteration 190 / 2000
# =================================================
# Start iteration 191 / 2000
# =================================================
# Start iteration 192 / 2000
# =================================================
# Start iteration 193 / 2000
# =================================================
# Start iteration 194 / 2000
# =================================================
# Start iteration 195 / 2000
# =================================================
# Start iteration 196 / 2000
# =================================================
# Start iteration 197 / 2000
# =================================================
# Start iteration 198 / 2000
# =================================================
# Start iteration 199 / 2000
# =================================================
# Start iteration 200 / 2000
# =================================================
# Start iteration 201 / 2000
# =================================================
# Start iteration 202 / 2000
# =================================================
# Start iteration 203 / 2000
# =================================================
# Start iteration 204 / 2000
# =================================================
# Start iteration 205 / 2000
# =================================================
# Start iteration 206 / 2000
# =================================================
# Start iteration 207 / 2000
# =================================================
# Start iteration 208 / 2000
# =================================================
# Start iteration 209 / 2000
# =================================================
# Start iteration 210 / 2000
# =================================================
# Start iteration 211 / 2000
# =================================================
# Start iteration 212 / 2000
# =================================================
# Start iteration 213 / 2000
# =================================================
# Start iteration 214 / 2000
# =================================================
# Start iteration 215 / 2000
# =================================================
# Start iteration 216 / 2000
# =================================================
# Start iteration 217 / 2000
# =================================================
# Start iteration 218 / 2000
# =================================================
# Start iteration 219 / 2000
# =================================================
# Start iteration 220 / 2000
# =================================================
# Start iteration 221 / 2000
# =================================================
# Start iteration 222 / 2000
# =================================================
# Start iteration 223 / 2000
# =================================================
# Start iteration 224 / 2000
# =================================================
# Start iteration 225 / 2000
# =================================================
# Start iteration 226 / 2000
# =================================================
# Start iteration 227 / 2000
# =================================================
# Start iteration 228 / 2000
# =================================================
# Start iteration 229 / 2000
# =================================================
# Start iteration 230 / 2000
# =================================================
# Start iteration 231 / 2000
# =================================================
# Start iteration 232 / 2000
# =================================================
# Start iteration 233 / 2000
# =================================================
# Start iteration 234 / 2000
# =================================================
# Start iteration 235 / 2000
# =================================================
# Start iteration 236 / 2000
# =================================================
# Start iteration 237 / 2000
# =================================================
# Start iteration 238 / 2000
# =================================================
# Start iteration 239 / 2000
# =================================================
# Start iteration 240 / 2000
# =================================================
# Start iteration 241 / 2000
# =================================================
# Start iteration 242 / 2000
# =================================================
# Start iteration 243 / 2000
# =================================================
# Start iteration 244 / 2000
# =================================================
# Start iteration 245 / 2000
# =================================================
# Start iteration 246 / 2000
# =================================================
# Start iteration 247 / 2000
# =================================================
# Start iteration 248 / 2000
# =================================================
# Start iteration 249 / 2000
# =================================================
# Start iteration 250 / 2000
# =================================================
# Start iteration 251 / 2000
# =================================================
# Start iteration 252 / 2000
# =================================================
# Start iteration 253 / 2000
# =================================================
# Start iteration 254 / 2000
# =================================================
# Start iteration 255 / 2000
# =================================================
# Start iteration 256 / 2000
# =================================================
# Start iteration 257 / 2000
# =================================================
# Start iteration 258 / 2000
# =================================================
# Start iteration 259 / 2000
# =================================================
# Start iteration 260 / 2000
# =================================================
# Start iteration 261 / 2000
# =================================================
# Start iteration 262 / 2000
# =================================================
# Start iteration 263 / 2000
# =================================================
# Start iteration 264 / 2000
# =================================================
# Start iteration 265 / 2000
# =================================================
# Start iteration 266 / 2000
# =================================================
# Start iteration 267 / 2000
# =================================================
# Start iteration 268 / 2000
# =================================================
# Start iteration 269 / 2000
# =================================================
# Start iteration 270 / 2000
# =================================================
# Start iteration 271 / 2000
# =================================================
# Start iteration 272 / 2000
# =================================================
# Start iteration 273 / 2000
# =================================================
# Start iteration 274 / 2000
# =================================================
# Start iteration 275 / 2000
# =================================================
# Start iteration 276 / 2000
# =================================================
# Start iteration 277 / 2000
# =================================================
# Start iteration 278 / 2000
# =================================================
# Start iteration 279 / 2000
# =================================================
# Start iteration 280 / 2000
# =================================================
# Start iteration 281 / 2000
# =================================================
# Start iteration 282 / 2000
# =================================================
# Start iteration 283 / 2000
# =================================================
# Start iteration 284 / 2000
# =================================================
# Start iteration 285 / 2000
# =================================================
# Start iteration 286 / 2000
# =================================================
# Start iteration 287 / 2000
# =================================================
# Start iteration 288 / 2000
# =================================================
# Start iteration 289 / 2000
# =================================================
# Start iteration 290 / 2000
# =================================================
# Start iteration 291 / 2000
# =================================================
# Start iteration 292 / 2000
# =================================================
# Start iteration 293 / 2000
# =================================================
# Start iteration 294 / 2000
# =================================================
# Start iteration 295 / 2000
# =================================================
# Start iteration 296 / 2000
# =================================================
# Start iteration 297 / 2000
# =================================================
# Start iteration 298 / 2000
# =================================================
# Start iteration 299 / 2000
# =================================================
# Start iteration 300 / 2000
# =================================================
# Start iteration 301 / 2000
# =================================================
# Start iteration 302 / 2000
# =================================================
# Start iteration 303 / 2000
# =================================================
# Start iteration 304 / 2000
# =================================================
# Start iteration 305 / 2000
# =================================================
# Start iteration 306 / 2000
# =================================================
# Start iteration 307 / 2000
# =================================================
# Start iteration 308 / 2000
# =================================================
# Start iteration 309 / 2000
# =================================================
# Start iteration 310 / 2000
# =================================================
# Start iteration 311 / 2000
# =================================================
# Start iteration 312 / 2000
# =================================================
# Start iteration 313 / 2000
# =================================================
# Start iteration 314 / 2000
# =================================================
# Start iteration 315 / 2000
# =================================================
# Start iteration 316 / 2000
# =================================================
# Start iteration 317 / 2000
# =================================================
# Start iteration 318 / 2000
# =================================================
# Start iteration 319 / 2000
# =================================================
# Start iteration 320 / 2000
# =================================================
# Start iteration 321 / 2000
# =================================================
# Start iteration 322 / 2000
# =================================================
# Start iteration 323 / 2000
# =================================================
# Start iteration 324 / 2000
# =================================================
# Start iteration 325 / 2000
# =================================================
# Start iteration 326 / 2000
# =================================================
# Start iteration 327 / 2000
# =================================================
# Start iteration 328 / 2000
# =================================================
# Start iteration 329 / 2000
# =================================================
# Start iteration 330 / 2000
# =================================================
# Start iteration 331 / 2000
# =================================================
# Start iteration 332 / 2000
# =================================================
# Start iteration 333 / 2000
# =================================================
# Start iteration 334 / 2000
# =================================================
# Start iteration 335 / 2000
# =================================================
# Start iteration 336 / 2000
# =================================================
# Start iteration 337 / 2000
# =================================================
# Start iteration 338 / 2000
# =================================================
# Start iteration 339 / 2000
# =================================================
# Start iteration 340 / 2000
# =================================================
# Start iteration 341 / 2000
# =================================================
# Start iteration 342 / 2000
# =================================================
# Start iteration 343 / 2000
# =================================================
# Start iteration 344 / 2000
# =================================================
# Start iteration 345 / 2000
# =================================================
# Start iteration 346 / 2000
# =================================================
# Start iteration 347 / 2000
# =================================================
# Start iteration 348 / 2000
# =================================================
# Start iteration 349 / 2000
# =================================================
# Start iteration 350 / 2000
# =================================================
# Start iteration 351 / 2000
# =================================================
# Start iteration 352 / 2000
# =================================================
# Start iteration 353 / 2000
# =================================================
# Start iteration 354 / 2000
# =================================================
# Start iteration 355 / 2000
# =================================================
# Start iteration 356 / 2000
# =================================================
# Start iteration 357 / 2000
# =================================================
# Start iteration 358 / 2000
# =================================================
# Start iteration 359 / 2000
# =================================================
# Start iteration 360 / 2000
# =================================================
# Start iteration 361 / 2000
# =================================================
# Start iteration 362 / 2000
# =================================================
# Start iteration 363 / 2000
# =================================================
# Start iteration 364 / 2000
# =================================================
# Start iteration 365 / 2000
# =================================================
# Start iteration 366 / 2000
# =================================================
# Start iteration 367 / 2000
# =================================================
# Start iteration 368 / 2000
# =================================================
# Start iteration 369 / 2000
# =================================================
# Start iteration 370 / 2000
# =================================================
# Start iteration 371 / 2000
# =================================================
# Start iteration 372 / 2000
# =================================================
# Start iteration 373 / 2000
# =================================================
# Start iteration 374 / 2000
# =================================================
# Start iteration 375 / 2000
# =================================================
# Start iteration 376 / 2000
# =================================================
# Start iteration 377 / 2000
# =================================================
# Start iteration 378 / 2000
# =================================================
# Start iteration 379 / 2000
# =================================================
# Start iteration 380 / 2000
# =================================================
# Start iteration 381 / 2000
# =================================================
# Start iteration 382 / 2000
# =================================================
# Start iteration 383 / 2000
# =================================================
# Start iteration 384 / 2000
# =================================================
# Start iteration 385 / 2000
# =================================================
# Start iteration 386 / 2000
# =================================================
# Start iteration 387 / 2000
# =================================================
# Start iteration 388 / 2000
# =================================================
# Start iteration 389 / 2000
# =================================================
# Start iteration 390 / 2000
# =================================================
# Start iteration 391 / 2000
# =================================================
# Start iteration 392 / 2000
# =================================================
# Start iteration 393 / 2000
# =================================================
# Start iteration 394 / 2000
# =================================================
# Start iteration 395 / 2000
# =================================================
# Start iteration 396 / 2000
# =================================================
# Start iteration 397 / 2000
# =================================================
# Start iteration 398 / 2000
# =================================================
# Start iteration 399 / 2000
# =================================================
# Start iteration 400 / 2000
# =================================================
# Start iteration 401 / 2000
# =================================================
# Start iteration 402 / 2000
# =================================================
# Start iteration 403 / 2000
# =================================================
# Start iteration 404 / 2000
# =================================================
# Start iteration 405 / 2000
# =================================================
# Start iteration 406 / 2000
# =================================================
# Start iteration 407 / 2000
# =================================================
# Start iteration 408 / 2000
# =================================================
# Start iteration 409 / 2000
# =================================================
# Start iteration 410 / 2000
# =================================================
# Start iteration 411 / 2000
# =================================================
# Start iteration 412 / 2000
# =================================================
# Start iteration 413 / 2000
# =================================================
# Start iteration 414 / 2000
# =================================================
# Start iteration 415 / 2000
# =================================================
# Start iteration 416 / 2000
# =================================================
# Start iteration 417 / 2000
# =================================================
# Start iteration 418 / 2000
# =================================================
# Start iteration 419 / 2000
# =================================================
# Start iteration 420 / 2000
# =================================================
# Start iteration 421 / 2000
# =================================================
# Start iteration 422 / 2000
# =================================================
# Start iteration 423 / 2000
# =================================================
# Start iteration 424 / 2000
# =================================================
# Start iteration 425 / 2000
# =================================================
# Start iteration 426 / 2000
# =================================================
# Start iteration 427 / 2000
# =================================================
# Start iteration 428 / 2000
# =================================================
# Start iteration 429 / 2000
# =================================================
# Start iteration 430 / 2000
# =================================================
# Start iteration 431 / 2000
# =================================================
# Start iteration 432 / 2000
# =================================================
# Start iteration 433 / 2000
# =================================================
# Start iteration 434 / 2000
# =================================================
# Start iteration 435 / 2000
# =================================================
# Start iteration 436 / 2000
# =================================================
# Start iteration 437 / 2000
# =================================================
# Start iteration 438 / 2000
# =================================================
# Start iteration 439 / 2000
# =================================================
# Start iteration 440 / 2000
# =================================================
# Start iteration 441 / 2000
# =================================================
# Start iteration 442 / 2000
# =================================================
# Start iteration 443 / 2000
# =================================================
# Start iteration 444 / 2000
# =================================================
# Start iteration 445 / 2000
# =================================================
# Start iteration 446 / 2000
# =================================================
# Start iteration 447 / 2000
# =================================================
# Start iteration 448 / 2000
# =================================================
# Start iteration 449 / 2000
# =================================================
# Start iteration 450 / 2000
# =================================================
# Start iteration 451 / 2000
# =================================================
# Start iteration 452 / 2000
# =================================================
# Start iteration 453 / 2000
# =================================================
# Start iteration 454 / 2000
# =================================================
# Start iteration 455 / 2000
# =================================================
# Start iteration 456 / 2000
# =================================================
# Start iteration 457 / 2000
# =================================================
# Start iteration 458 / 2000
# =================================================
# Start iteration 459 / 2000
# =================================================
# Start iteration 460 / 2000
# =================================================
# Start iteration 461 / 2000
# =================================================
# Start iteration 462 / 2000
# =================================================
# Start iteration 463 / 2000
# =================================================
# Start iteration 464 / 2000
# =================================================
# Start iteration 465 / 2000
# =================================================
# Start iteration 466 / 2000
# =================================================
# Start iteration 467 / 2000
# =================================================
# Start iteration 468 / 2000
# =================================================
# Start iteration 469 / 2000
# =================================================
# Start iteration 470 / 2000
# =================================================
# Start iteration 471 / 2000
# =================================================
# Start iteration 472 / 2000
# =================================================
# Start iteration 473 / 2000
# =================================================
# Start iteration 474 / 2000
# =================================================
# Start iteration 475 / 2000
# =================================================
# Start iteration 476 / 2000
# =================================================
# Start iteration 477 / 2000
# =================================================
# Start iteration 478 / 2000
# =================================================
# Start iteration 479 / 2000
# =================================================
# Start iteration 480 / 2000
# =================================================
# Start iteration 481 / 2000
# =================================================
# Start iteration 482 / 2000
# =================================================
# Start iteration 483 / 2000
# =================================================
# Start iteration 484 / 2000
# =================================================
# Start iteration 485 / 2000
# =================================================
# Start iteration 486 / 2000
# =================================================
# Start iteration 487 / 2000
# =================================================
# Start iteration 488 / 2000
# =================================================
# Start iteration 489 / 2000
# =================================================
# Start iteration 490 / 2000
# =================================================
# Start iteration 491 / 2000
# =================================================
# Start iteration 492 / 2000
# =================================================
# Start iteration 493 / 2000
# =================================================
# Start iteration 494 / 2000
# =================================================
# Start iteration 495 / 2000
# =================================================
# Start iteration 496 / 2000
# =================================================
# Start iteration 497 / 2000
# =================================================
# Start iteration 498 / 2000
# =================================================
# Start iteration 499 / 2000
# =================================================
# Start iteration 500 / 2000
# =================================================
# Start iteration 501 / 2000
# =================================================
# Start iteration 502 / 2000
# =================================================
# Start iteration 503 / 2000
# =================================================
# Start iteration 504 / 2000
# =================================================
# Start iteration 505 / 2000
# =================================================
# Start iteration 506 / 2000
# =================================================
# Start iteration 507 / 2000
# =================================================
# Start iteration 508 / 2000
# =================================================
# Start iteration 509 / 2000
# =================================================
# Start iteration 510 / 2000
# =================================================
# Start iteration 511 / 2000
# =================================================
# Start iteration 512 / 2000
# =================================================
# Start iteration 513 / 2000
# =================================================
# Start iteration 514 / 2000
# =================================================
# Start iteration 515 / 2000
# =================================================
# Start iteration 516 / 2000
# =================================================
# Start iteration 517 / 2000
# =================================================
# Start iteration 518 / 2000
# =================================================
# Start iteration 519 / 2000
# =================================================
# Start iteration 520 / 2000
# =================================================
# Start iteration 521 / 2000
# =================================================
# Start iteration 522 / 2000
# =================================================
# Start iteration 523 / 2000
# =================================================
# Start iteration 524 / 2000
# =================================================
# Start iteration 525 / 2000
# =================================================
# Start iteration 526 / 2000
# =================================================
# Start iteration 527 / 2000
# =================================================
# Start iteration 528 / 2000
# =================================================
# Start iteration 529 / 2000
# =================================================
# Start iteration 530 / 2000
# =================================================
# Start iteration 531 / 2000
# =================================================
# Start iteration 532 / 2000
# =================================================
# Start iteration 533 / 2000
# =================================================
# Start iteration 534 / 2000
# =================================================
# Start iteration 535 / 2000
# =================================================
# Start iteration 536 / 2000
# =================================================
# Start iteration 537 / 2000
# =================================================
# Start iteration 538 / 2000
# =================================================
# Start iteration 539 / 2000
# =================================================
# Start iteration 540 / 2000
# =================================================
# Start iteration 541 / 2000
# CPU times: user 5min 7s, sys: 35.6 s, total: 5min 43s
# Wall time: 5min 38s
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'from src.run_assimilator import run_assimilator\n\n# Change the following parameters to reproduce the different experimental results\n# Changing A and epsilon will require to have downloaded the corresponding files.\n# If you are trying values of A and epsilon that do not have a corresponding dispersion file, you will have to generate it with the double gyre code\n\nmu = 2\nA = 0.1\nepsilon = 0.25\nsigma_rel = 0.01\nOBSERVATION_LOCATIONS = [(12, 4), (55, 27)]\n\nif __name__ == "__main__":\n    run_assimilator(\n        particles_dataset_path="data/parts_double_gyre_standard_as_3.nc",\n        observations_type="from_simulation",\n        observations_source_path=f"data/parts_double_gyre_ref_eps_{epsilon}_A_{A}_as_2.nc",\n        simulation_name=f"mu_{mu}_A_{A}_eps_{epsilon}_sigma_rel_{sigma_rel}_obspoints_{OBSERVATION_LOCATIONS}",\n        assimilation_domain_coords=(195, 20, 225, 40),\n        assimilation_grid_size=(60, 40),\n        size_ensemble=10,\n        initial_ensemble_spread=0.05,\n        t_start=0,\n        t_end=2000,\n        observations_error_percent=sigma_rel,\n        observation_locations=OBSERVATION_LOCATIONS,\n        initial_mass_multiplicator=mu,\n    )\n')
#
# File <timed exec>:14
#
# File ~/Documents/Ocean-Plastic-Assimilator-Original/src/run_assimilator.py:188, in run_assimilator(particles_dataset_path, observations_type, observations_source_path, assimilation_domain_coords, assimilation_grid_size, size_ensemble, initial_ensemble_spread, t_start, t_end, initial_mass_multiplicator, radius_observation, reinit_spreading, metrics_plot_period, observations_error_percent, observation_locations, measure_resolution, simulation_name, csv_reader_options, verbose, computations_data_dir, cells_area)
#     158 config = AssimilatorConfig(
#     159     size_ensemble=size_ensemble,
#     160     ensemble_spread=initial_ensemble_spread,
#    (...)    183     verbose=verbose,
#     184 )
#     186 init_data(datapaths, config)
# --> 188 start_simulation(datapaths, config)
#
# File ~/Documents/Ocean-Plastic-Assimilator-Original/src/assimilation/start_simulation.py:111, in start_simulation(datapaths, config)
#     109             if config.verbose:
#     110                 print("Generating heatmaps and distributions")
# --> 111             metrics.plot_metrics(densities_ensemble, densities_ref, weights, t + 1)
#     113 except KeyboardInterrupt:
#     114     print("Asked for interruption!")
#
# File ~/Documents/Ocean-Plastic-Assimilator-Original/src/io/Metrics.py:130, in Metrics.plot_metrics(self, densities_ensemble, densities_ref, weights_ensemble, t)
#     122 def plot_metrics(
#     123     self,
#     124     densities_ensemble: np.ndarray,
#    (...)    127     t: int,
#     128 ):
#     129     if self.observation_type == ObservationsType.from_simulation:
# --> 130         self._plot_metrics_from_sim(
#     131             densities_ensemble=densities_ensemble,
#     132             densities_ref=densities_ref,
#     133             weights_ensemble=weights_ensemble,
#     134             t=t,
#     135         )
#     137     if self.observation_type == ObservationsType.from_csv:
#     138         self._plot_metrics_from_csv(
#     139             densities_ensemble=densities_ensemble,
#     140             weights_ensemble=weights_ensemble,
#     141             t=t,
#     142         )
#
# File ~/Documents/Ocean-Plastic-Assimilator-Original/src/io/Metrics.py:201, in Metrics._plot_metrics_from_sim(self, densities_ensemble, densities_ref, weights_ensemble, t)
#     198 cfrms_df["Objective"] = 0
#     199 sns.lineplot(data=cfrms_df, ax=axs[1, 2])
# --> 201 self.csv_logger.export_csv()
#     202 fig.savefig(f"{self.output_dir_path}metrics_{t}.png")
#     203 plt.close("all")
#
# File ~/Documents/Ocean-Plastic-Assimilator-Original/src/io/CSV_Logger.py:20, in CSV_Logger.export_csv(self)
#      19 def export_csv(self):
# ---> 20     self.df.to_csv(self.path + ".csv")
#
# File ~/miniconda3/envs/ocean-plastic-assimilator-fresh/lib/python3.14/site-packages/pandas/core/generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3984             float_format=float_format,
#    3985             decimal=decimal,
#    3986         )
#    3987
# -> 3988         return DataFrameRenderer(formatter).to_csv(
#    3989             path_or_buf,
#    3990             lineterminator=lineterminator,
#    3991             sep=sep,
#
# File ~/miniconda3/envs/ocean-plastic-assimilator-fresh/lib/python3.14/site-packages/pandas/io/formats/format.py:1025, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1004     created_buffer = False
#    1006 csv_formatter = CSVFormatter(
#    1007     path_or_buf=path_or_buf,
#    1008     lineterminator=lineterminator,
#    (...)   1023     formatter=self.fmt,
#    1024 )
# -> 1025 csv_formatter.save()
#    1027 if created_buffer:
#    1028     assert isinstance(path_or_buf, StringIO)
#
# File ~/miniconda3/envs/ocean-plastic-assimilator-fresh/lib/python3.14/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     # error: Argument "quoting" to "writer" has incompatible type "int";
#     261     # expected "Literal[0, 1, 2, 3]"
#     262     self.writer = csvlib.writer(
#     263         handles.handle,
#     264         lineterminator=self.lineterminator,
#    (...)    269         quotechar=self.quotechar,
#     270     )
#     272     self._save()
#
# File ~/miniconda3/envs/ocean-plastic-assimilator-fresh/lib/python3.14/site-packages/pandas/io/common.py:793, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     791 # Only for write methods
#     792 if "r" not in mode and is_path:
# --> 793     check_parent_directory(str(handle))
#     795 if compression:
#     796     if compression != "zstd":
#     797         # compression libraries do not like an explicit text-mode
#
# File ~/miniconda3/envs/ocean-plastic-assimilator-fresh/lib/python3.14/site-packages/pandas/io/common.py:652, in check_parent_directory(path)
#     650 parent = Path(path).parent
#     651 if not parent.is_dir():
# --> 652     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'outputs/output_mu_2_A_0.1_eps_0.25_sigma_rel_0.01_obspoints_[(12, 4), (55, 27)]'

# %% [markdown]
# ## 2. Run a self-assimilation experiment with observation sampled a dispersion model assimilated into another dispersion model

# %%
# First, download the data if it's not present, and prepare it

import xarray as xr
import numpy as np
from datetime import datetime
from dask.diagnostics import ProgressBar
import wget
from pathlib import Path

files_to_download = ["advector_output_rivers_2012.nc", "advector_output_coastal_2012.nc"]

Path("data/").mkdir(exist_ok=True)
for file_to_download in files_to_download:
  if not Path(f"data/{file_to_download}").exists():
    print(f"Downloading {file_to_download}...")
    wget.download(f"https://zenodo.org/record/4740138/files/{file_to_download}", f"data/{file_to_download}")

ds_in = xr.open_dataset("data/advector_output_coastal_2012.nc", chunks="auto")
years_release = ds_in.release_date.dt.year
days_release = ds_in.release_date.dt.dayofyear
arg_release = (years_release - 1993) + days_release / 366

def increasing_sine(x):
    return x + (1 / (2 * np.pi)) * np.sin(2 * np.pi * x + np.pi)

# 1 tonne per particle, as sensible value for a global plastic dispersion model
ds_in["weight"] = 1000 + 1000 * increasing_sine(arg_release)
with ProgressBar():
    ds_in.to_netcdf("data/advector_output_coastal_2012_adapted.nc")

# %%
# Run the Ocean Plastic Assimilator

from src.run_assimilator import run_assimilator
import numpy as np

cell_area = lambda dlon,dlat,lat: dlat * 111 * dlon * 111 * np.cos(lat * np.pi / 180)

GRID_COORDS = (-165, 23, -125, 45)
GRID_RESOLUTION = 0.5

cells_area = np.array([[cell_area(0.5, 0.5, lat_id * GRID_RESOLUTION + GRID_COORDS[1]) for lat_id in range(44)] for lon_id in range(80)])

if __name__ == "__main__":
    run_assimilator(
        particles_dataset_path="data/advector_output_rivers_2012.nc",
        observations_type="from_simulation",
        observations_source_path="data/advector_output_coastal_2012_adapted.nc",
        assimilation_domain_coords=GRID_COORDS,
        assimilation_grid_size=(int(40 / GRID_RESOLUTION), int(22 / GRID_RESOLUTION)),
        size_ensemble=10,
        initial_ensemble_spread=50,
        observations_error_percent=0.01,
        observation_locations=[(25, 12), (50, 24)],
        t_start=0,
        t_end=360,
        initial_mass_multiplicator=1000,
        radius_observation=np.inf,
        simulation_name="self_assimilation_gpgp",
        cells_area=cells_area,
    )
