# %% [markdown]
# # Running the experiments of the paper

# %% [markdown]
# ## 1. Run the assimilator double gyre experiments on double gyre files

# %%
# Download the data, if necessary

import wget
from pathlib import Path

files_to_download = ["parts_double_gyre_ref_eps_0.25_A_0.1175_as_2.nc", "parts_double_gyre_ref_eps_0.25_A_0.105_as_2.nc",
"parts_double_gyre_ref_eps_0.25_A_0.11_as_2.nc",
"parts_double_gyre_ref_eps_0.25_A_0.125_as_2.nc",
"parts_double_gyre_ref_eps_0.25_A_0.1_as_2.nc",
"parts_double_gyre_ref_eps_0.35_A_0.1_as_2.nc",
"parts_double_gyre_ref_eps_0.3_A_0.1_as_2.nc",
"parts_double_gyre_ref_eps_0.4_A_0.1_as_2.nc",
"parts_double_gyre_ref_eps_0.5_A_0.1_as_2.nc",
"parts_double_gyre_ref_eps_0_A_0.1_as_2.nc",
"parts_double_gyre_ref_eps_1_A_0.1_as_2.nc",
"parts_double_gyre_standard_as_3.nc"]

Path("data/").mkdir(exist_ok=True)
for file_to_download in files_to_download:
  if not Path(f"data/{file_to_download}").exists():
    print(f"Downloading {file_to_download}...")
    wget.download(f"https://zenodo.org/record/4426130/files/{file_to_download}", f"data/{file_to_download}")

print("All files required for experiment have been downloaded")

# %%
# %%time
# %%prun
from src.run_assimilator import run_assimilator

# Change the following parameters to reproduce the different experimental results
# Changing A and epsilon will require to have downloaded the corresponding files.
# If you are trying values of A and epsilon that do not have a corresponding dispersion file, you will have to generate it with the double gyre code

mu = 2
A = 0.1
epsilon = 0.25
sigma_rel = 0.01
OBSERVATION_LOCATIONS = [(12, 4), (55, 27)]

if __name__ == "__main__":
    run_assimilator(
        particles_dataset_path="data/parts_double_gyre_standard_as_3.nc",
        observations_type="from_simulation",
        observations_source_path=f"data/parts_double_gyre_ref_eps_{epsilon}_A_{A}_as_2.nc",
        simulation_name=f"mu_{mu}_A_{A}_eps_{epsilon}_sigma_rel_{sigma_rel}_obspoints_{OBSERVATION_LOCATIONS}",
        assimilation_domain_coords=(195, 20, 225, 40),
        assimilation_grid_size=(60, 40),
        size_ensemble=10,
        initial_ensemble_spread=0.05,
        t_start=0,
        t_end=2000,
        observations_error_percent=sigma_rel,
        observation_locations=OBSERVATION_LOCATIONS,
        initial_mass_multiplicator=mu,
    )
# Out:
# Successfully created data/data_mu_2_A_0.1_eps_0.25_sigma_rel_0.01_obspoints_[(12, 4), (55, 27)]/
# Successfully created outputs/output_mu_2_A_0.1_eps_0.25_sigma_rel_0.01_obspoints_[(12, 4), (55, 27)]/
# Start iterating
# =================================================
# Start iteration 1 / 2000
# =================================================
# Start iteration 2 / 2000
# =================================================
# Start iteration 3 / 2000
# =================================================
# Start iteration 4 / 2000
# =================================================
# Start iteration 5 / 2000
# =================================================
# Start iteration 6 / 2000
# =================================================
# Start iteration 7 / 2000
# =================================================
# Start iteration 8 / 2000
# =================================================
# Start iteration 9 / 2000
# =================================================
# Start iteration 10 / 2000
# Saving everything now...
# Do not interrupt.
#  CPU times: user 10.1 s, sys: 2.13 s, total: 12.2 s
# Wall time: 8.34 s
#          15546751 function calls (15487772 primitive calls) in 8.323 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    346096    0.829    0.000    1.817    0.000 core.py:3283(__getitem__)
#    329523    0.586    0.000    0.981    0.000 core.py:3015(_update_from)
#        11    0.518    0.047    1.397    0.127 Metrics.py:44(log_metrics)
#         1    0.322    0.322    0.657    0.657 density_computations_ensemble.py:10(compute_ensemble_densities_over_time)
#        37    0.264    0.007    6.669    0.180 {method 'poll' of 'select.epoll' objects}
#    277001    0.253    0.000    0.253    0.000 utils.py:473(_is_int)
#     23400    0.250    0.000    0.701    0.000 core.py:1196(__call__)
# 2942205/2941995    0.228    0.000    0.249    0.000 {built-in method builtins.getattr}
#         7    0.225    0.032    0.891    0.127 {built-in method time.sleep}
#        37    0.200    0.005    9.207    0.249 selectors.py:435(select)
#        10    0.187    0.019    0.235    0.024 assimilate.py:117(compute_corrections)
# 1021801/1021800    0.181    0.000    1.021    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.176    0.176    1.265    1.265 init_data.py:127(init_data)
#   1488079    0.170    0.000    0.170    0.000 {method 'update' of 'dict' objects}
# 1998924/1998513    0.165    0.000    0.179    0.000 {built-in method builtins.isinstance}
#    165018    0.159    0.000    0.841    0.000 core.py:3040(__array_finalize__)
#     23486    0.156    0.000    0.571    0.000 core.py:1050(__call__)
#    856525    0.154    0.000    0.271    0.000 core.py:3761(_get_data)
#         2    0.130    0.065    0.142    0.071 density_preparation.py:17(prepare_density_inputs)
#         1    0.127    0.127    0.130    0.130 init_data.py:91(compute_parts_ensemble)
#     93577    0.122    0.000    0.202    0.000 numeric.py:1431(normalize_axis_tuple)
#     23480    0.108    0.000    0.144    0.000 core.py:3411(__setitem__)
#     37776    0.106    0.000    0.107    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     46771    0.101    0.000    0.830    0.000 numeric.py:1493(moveaxis)
#     23424    0.091    0.000    0.134    0.000 core.py:888(__call__)
#        59    0.080    0.001    0.829    0.014 utils.py:81(_StartCountStride)
#        10    0.072    0.007    1.882    0.188 assimilate.py:169(update_weights)
#    441367    0.072    0.000    0.072    0.000 core.py:3482(dtype)
#    165165    0.069    0.000    0.069    0.000 {method 'view' of 'numpy.generic' objects}
#     46821    0.069    0.000    0.502    0.000 core.py:2631(wrapped_method)
#         2    0.067    0.034    0.067    0.034 {built-in method posix.sendfile}
#    322533    0.066    0.000    0.089    0.000 core.py:3300(_scalar_heuristic)
# 600064/593479    0.050    0.000    0.051    0.000 {built-in method builtins.len}
#     46886    0.049    0.000    0.063    0.000 core.py:681(get_masked_subclass)
#    284051    0.046    0.000    0.070    0.000 core.py:1400(getmask)
#        21    0.045    0.002    0.045    0.002 numeric.py:170(ones)
#         1    0.042    0.042    0.044    0.044 start_simulation.py:11(start_simulation)
#        10    0.039    0.004    0.230    0.023 assimilate.py:43(compute_covariances)
#     48000    0.038    0.000    0.042    0.000 localization.py:22(loc_factor)
#        20    0.037    0.002    0.040    0.002 localization.py:41(compute_indices_circle)
#         4    0.036    0.009    0.036    0.009 {method 'encode' of 'ImagingEncoder' objects}
#         1    0.036    0.036    0.146    0.146 density_computations.py:31(compute_densities)
#    117578    0.036    0.000    0.036    0.000 {method 'set' of '_contextvars.ContextVar' objects}
#        37    0.034    0.001   10.005    0.270 base_events.py:1966(_run_once)
#     70612    0.034    0.000    0.072    0.000 _ufunc_config.py:472(__enter__)
#    240235    0.031    0.000    0.033    0.000 {built-in method builtins.sum}
#       525    0.029    0.000    0.029    0.000 {built-in method matplotlib.ft2font.set_text}
#     23480    0.028    0.000    0.192    0.000 _ufunc_config.py:496(inner)
#    187154    0.028    0.000    0.040    0.000 numeric.py:1480(<genexpr>)
#     94092    0.027    0.000    0.027    0.000 {method 'reset' of '_contextvars.ContextVar' objects}
#    117578    0.026    0.000    0.026    0.000 {built-in method numpy._core._multiarray_umath._make_extobj}
#     23486    0.026    0.000    0.065    0.000 _ufunc_config.py:19(seterr)
#      1398    0.023    0.000    0.121    0.000 text.py:358(_get_layout)
#       579    0.023    0.000    0.023    0.000 numeric.py:323(full)
#     70564    0.022    0.000    0.034    0.000 core.py:822(is_string_or_list_of_strings)
#     93564    0.020    0.000    0.020    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#     94087    0.020    0.000    0.055    0.000 core.py:708(getdata)
#     23486    0.020    0.000    0.020    0.000 {built-in method numpy._core._multiarray_umath._get_extobj_dict}
#     70612    0.019    0.000    0.040    0.000 _ufunc_config.py:488(__exit__)
#     23400    0.018    0.000    0.728    0.000 core.py:4354(__truediv__)
#         1    0.017    0.017    0.017    0.017 init_data.py:25(recompute_ensemble_densities)
#     28669    0.017    0.000    0.017    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     23412    0.016    0.000    0.590    0.000 core.py:4339(__mul__)
#     50429    0.015    0.000    0.016    0.000 {built-in method builtins.sorted}
#     46865    0.014    0.000    0.018    0.000 core.py:4178(_delegate_binop)
# 4219/3511    0.014    0.000    0.112    0.000 artist.py:1188(_update_props)
#      9955    0.014    0.000    0.021    0.000 font_manager.py:700(__hash__)
#     93816    0.013    0.000    0.013    0.000 {built-in method numpy.lib.array_utils.normalize_axis_index}
# 8670/8640    0.012    0.000    0.017    0.000 {built-in method numpy.array}
# 59386/59290    0.012    0.000    0.015    0.000 {built-in method numpy.asarray}
#    107438    0.011    0.000    0.011    0.000 {built-in method builtins.issubclass}
#     24376    0.010    0.000    0.046    0.000 {method 'any' of 'numpy.ndarray' objects}
#     12036    0.010    0.000    0.024    0.000 copy.py:62(copy)
#     15283    0.010    0.000    0.010    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       144    0.010    0.000    0.011    0.000 {built-in method matplotlib.backends._backend_agg.draw_path}
#     93606    0.009    0.000    0.009    0.000 {built-in method _operator.index}
#      3290    0.009    0.000    0.012    0.000 cbook.py:1752(normalize_kwargs)
# 24569/501    0.009    0.000    0.026    0.000 copy.py:110(deepcopy)
#     70612    0.009    0.000    0.009    0.000 _ufunc_config.py:462(__init__)
#     10344    0.009    0.000    0.014    0.000 cbook.py:2020(_setattr_cm)
#        18    0.009    0.000    0.009    0.001 {built-in method matplotlib.backends._backend_agg.draw_quad_mesh}
#     34123    0.009    0.000    0.019    0.000 __init__.py:781(__getitem__)
# 52066/45943    0.008    0.000    0.013    0.000 artist.py:315(stale)
#     64816    0.008    0.000    0.008    0.000 {method 'get' of 'dict' objects}
#      1077    0.008    0.000    0.137    0.000 text.py:738(draw)
#       427    0.008    0.000    0.009    0.000 {built-in method matplotlib.backends._backend_agg.draw_markers}
#     24536    0.008    0.000    0.063    0.000 _methods.py:55(_any)
#        20    0.008    0.000    0.009    0.000 density_preparation.py:72(prepare_cell_ids_for_time)
#      1299    0.008    0.000    0.059    0.000 lines.py:758(draw)
#     52033    0.008    0.000    0.008    0.000 {method 'pop' of 'dict' objects}
#        10    0.008    0.001    0.109    0.011 localization.py:8(create_localization_matrix)
#       657    0.008    0.000    0.052    0.000 lines.py:301(__init__)
# 9200/9176    0.008    0.000    0.013    0.000 cbook.py:348(process)
#     23427    0.007    0.000    0.022    0.000 core.py:7630(reshape)
#       732    0.007    0.000    0.009    0.000 _shape_base_impl.py:625(column_stack)
#     47225    0.007    0.000    0.007    0.000 {method 'insert' of 'list' objects}
# 2102/1792    0.007    0.000    0.013    0.000 transforms.py:2432(get_affine)
#       434    0.007    0.000    0.007    0.000 {built-in method matplotlib.backends._backend_agg.draw_text_image}
#       660    0.007    0.000    0.024    0.000 lines.py:686(recache)
#      5286    0.007    0.000    0.017    0.000 copy.py:228(_reconstruct)
#       139    0.006    0.000    0.011    0.000 core.py:3856(filled)
#     34123    0.006    0.000    0.011    0.000 __init__.py:701(_get)
#     24206    0.006    0.000    0.006    0.000 core.py:3498(shape)
#     72560    0.006    0.000    0.006    0.000 {method 'append' of 'list' objects}
#     23427    0.006    0.000    0.008    0.000 core.py:3297(_is_scalar)
#        10    0.006    0.001    0.015    0.001 density_computations_ensemble.py:75(compute_ensemble_densities_over_parts)
#      1577    0.006    0.000    0.011    0.000 artist.py:179(__init__)
#     17714    0.006    0.000    0.007    0.000 __init__.py:100(check_in_list)
#     53390    0.006    0.000    0.006    0.000 {method 'items' of 'dict' objects}
#       934    0.005    0.000    0.109    0.000 text.py:926(get_window_extent)
#       737    0.005    0.000    0.021    0.000 construction.py:531(sanitize_array)
#      4014    0.005    0.000    0.011    0.000 transforms.py:750(__init__)
#     10123    0.005    0.000    0.007    0.000 transforms.py:1770(__init__)
#    3273/7    0.005    0.000    0.530    0.076 artist.py:53(draw_wrapper)
#     46771    0.005    0.000    0.005    0.000 numeric.py:1489(_moveaxis_dispatcher)
#      4654    0.005    0.000    0.005    0.000 {built-in method matplotlib._path.affine_transform}
#     54812    0.005    0.000    0.005    0.000 {built-in method builtins.max}
#       287    0.005    0.000    0.008    0.000 string_arrow.py:194(_from_sequence)
#       212    0.005    0.000    0.108    0.001 axis.py:59(__init__)
# 11929/10181    0.005    0.000    0.034    0.000 {built-in method builtins.next}
#     34123    0.004    0.000    0.004    0.000 {function RcParams.__getitem__ at 0x74ad73752140}
#       194    0.004    0.000    0.171    0.001 axis.py:1276(_update_ticks)
#      5307    0.004    0.000    0.010    0.000 transforms.py:1887(__init__)
#      2826    0.004    0.000    0.049    0.000 text.py:65(_get_text_metrics_with_cache)
#       234    0.004    0.000    0.028    0.000 ticker.py:2159(_raw_ticks)
#     16373    0.004    0.000    0.004    0.000 transforms.py:109(__init__)
#       229    0.004    0.000    0.004    0.000 compute.py:467(take)
#     30585    0.004    0.000    0.005    0.000 {built-in method _abc._abc_instancecheck}
#      5624    0.004    0.000    0.005    0.000 contextlib.py:108(__init__)
#      3161    0.004    0.000    0.006    0.000 __init__.py:65(check_isinstance)
#     30585    0.004    0.000    0.009    0.000 <frozen abc>:117(__instancecheck__)
#     31270    0.004    0.000    0.004    0.000 multiarray.py:1085(copyto)
#      2190    0.004    0.000    0.009    0.000 fromnumeric.py:38(_wrapit)
#  1494/498    0.004    0.000    0.025    0.000 copy.py:198(_deepcopy_dict)
#       194    0.004    0.000    0.007    0.000 numeric.py:2384(isclose)
#        10    0.004    0.000    0.004    0.000 {method 'repeat' of 'numpy.ndarray' objects}
# 18658/12082    0.004    0.000    0.016    0.000 {built-in method builtins.hash}
# 1301/1217    0.004    0.000    0.014    0.000 _base.py:887(_unstale_viewLim)
#      3085    0.003    0.000    0.004    0.000 transforms.py:180(set_children)
# 4654/4653    0.003    0.000    0.009    0.000 transforms.py:1849(transform_affine)
#      4629    0.003    0.000    0.009    0.000 colors.py:278(to_rgba)
#       100    0.003    0.000    0.003    0.000 core.py:4402(__iadd__)
#      9061    0.003    0.000    0.016    0.000 artist.py:414(pchanged)
#     25007    0.003    0.000    0.012    0.000 _base.py:733(<genexpr>)
#      1681    0.003    0.000    0.006    0.000 transforms.py:1973(rotate)
#      5286    0.003    0.000    0.003    0.000 {method '__reduce_ex__' of 'object' objects}
#       102    0.003    0.000    0.042    0.000 _methods.py:115(_mean)
#      4257    0.003    0.000    0.005    0.000 lines.py:1309(set_ydata)
#      3968    0.003    0.000    0.008    0.000 fromnumeric.py:66(_wrapreduction)
#         2    0.003    0.001    0.006    0.003 {method '__exit__' of 'sqlite3.Connection' objects}
#      2869    0.003    0.000    0.013    0.000 fromnumeric.py:48(_wrapfunc)
# 16894/16882    0.003    0.000    0.003    0.000 {built-in method builtins.hasattr}
#      5624    0.003    0.000    0.008    0.000 contextlib.py:303(helper)
#       206    0.003    0.000    0.004    0.000 core.py:1748(mask_or)
#       990    0.003    0.000    0.006    0.000 artist.py:1167(update_from)
#      1579    0.003    0.000    0.035    0.000 markers.py:299(_set_marker)
#      1678    0.003    0.000    0.022    0.000 transforms.py:1473(transform)
#     23408    0.003    0.000    0.003    0.000 multiarray.py:600(can_cast)
#       565    0.003    0.000    0.023    0.000 text.py:157(_reset_visual_defaults)
#      6365    0.003    0.000    0.004    0.000 enum.py:677(__call__)
#      2840    0.002    0.000    0.007    0.000 common.py:1821(pandas_dtype)
#       434    0.002    0.000    0.002    0.000 {built-in method matplotlib.ft2font.draw_glyphs_to_bitmap}
#      3492    0.002    0.000    0.005    0.000 lines.py:1290(set_xdata)
#     11067    0.002    0.000    0.004    0.000 _function_base_impl.py:363(iterable)
#      1848    0.002    0.000    0.016    0.000 transforms.py:805(from_extents)
# 5624/5187    0.002    0.000    0.019    0.000 contextlib.py:145(__exit__)
#      5929    0.002    0.000    0.005    0.000 colors.py:219(_is_nth_color)
#         3    0.002    0.001    0.002    0.001 backend_agg.py:63(__init__)
#       434    0.002    0.000    0.053    0.000 backend_agg.py:185(draw_text)
#       780    0.002    0.000    0.005    0.000 string_arrow.py:133(__init__)
# 4759/4061    0.002    0.000    0.003    0.000 transforms.py:165(_invalidate_internal)
#       840    0.002    0.000    0.003    0.000 generic.py:6131(__finalize__)
#       311    0.002    0.000    0.024    0.000 base.py:486(__new__)
#        28    0.002    0.000    0.002    0.000 {method 'partition' of 'numpy.ndarray' objects}
#      1425    0.002    0.000    0.002    0.000 transforms.py:2918(_interval_contains_close)
#       2/1    0.002    0.001    0.046    0.046 run_assimilator.py:49(run_assimilator)
#      9047    0.002    0.000    0.003    0.000 artist.py:723(get_figure)
#     11278    0.002    0.000    0.003    0.000 {built-in method builtins.setattr}
#      7271    0.002    0.000    0.003    0.000 {built-in method numpy.asanyarray}
#       907    0.002    0.000    0.003    0.000 __init__.py:147(check_shape)
#      1038    0.002    0.000    0.007    0.000 backend_bases.py:680(__init__)
#      1426    0.002    0.000    0.003    0.000 transforms.py:2041(scale)
#      9165    0.002    0.000    0.005    0.000 generic.py:43(_instancecheck)
#       491    0.002    0.000    0.005    0.000 array.py:722(__getitem__)
# 2689/2319    0.002    0.000    0.105    0.000 artist.py:1237(set)
# 5624/5187    0.002    0.000    0.021    0.000 contextlib.py:136(__enter__)
#       427    0.002    0.000    0.196    0.000 axis.py:268(draw)
#      3478    0.002    0.000    0.005    0.000 artist.py:102(_stale_axes_callback)
#       937    0.002    0.000    0.004    0.000 transforms.py:617(translated)
#      9165    0.002    0.000    0.003    0.000 generic.py:38(_check)
#     11215    0.002    0.000    0.002    0.000 {built-in method __new__ of type object at 0x623d5751d1e0}
#      1720    0.002    0.000    0.002    0.000 cbook.py:259(__init__)
#      6068    0.002    0.000    0.003    0.000 weakref.py:356(get)
#       553    0.002    0.000    0.009    0.000 font_manager.py:1293(findfont)
#       311    0.002    0.000    0.003    0.000 array.py:1671(to_numpy)
#      1832    0.002    0.000    0.004    0.000 text.py:1292(_preprocess_math)
#     18654    0.002    0.000    0.002    0.000 artist.py:292(axes)
#         7    0.002    0.000    0.002    0.000 {built-in method matplotlib.backends._backend_agg.clear}
#         4    0.002    0.000    0.031    0.008 _base.py:695(_assign_variables_wideform)
#       803    0.002    0.000    0.008    0.000 font_manager.py:656(__init__)
#      5790    0.002    0.000    0.002    0.000 {method 'match' of 're.Pattern' objects}
#      1628    0.002    0.000    0.004    0.000 common.py:1659(_is_dtype_type)
# 2689/2319    0.002    0.000    0.106    0.000 artist.py:146(<lambda>)
#       384    0.002    0.000    0.002    0.000 transforms.py:2838(nonsingular)
#         1    0.002    0.002    0.148    0.148 init_data.py:13(recompute_ref_densities)
#      5283    0.002    0.000    0.002    0.000 copyreg.py:103(__newobj__)
#     14015    0.002    0.000    0.002    0.000 {method 'values' of 'dict' objects}
#        30    0.002    0.000    0.002    0.000 {built-in method builtins.eval}
#       988    0.002    0.000    0.008    0.000 axis.py:467(update_position)
#      4271    0.002    0.000    0.024    0.000 font_manager.py:961(copy)
#       194    0.002    0.000    0.029    0.000 axis.py:1527(get_minorticklocs)
#      4318    0.002    0.000    0.002    0.000 copy.py:212(_keep_alive)
#      3034    0.002    0.000    0.005    0.000 cbook.py:871(get_siblings)
#      2489    0.002    0.000    0.002    0.000 cbook.py:1334(is_math_text)
#      4061    0.002    0.000    0.005    0.000 transforms.py:156(invalidate)
#       525    0.002    0.000    0.003    0.000 font_manager.py:1586(get_font)
#       265    0.002    0.000    0.005    0.000 managers.py:879(_slice_take_blocks_ax0)
# 5202/2761    0.002    0.000    0.002    0.000 transforms.py:2401(<lambda>)
#         1    0.002    0.002    0.002    0.002 init_data.py:56(create_datasets)
#      1971    0.002    0.000    0.003    0.000 lines.py:1217(_set_markercolor)
#        28    0.002    0.000    0.002    0.000 algorithms.py:590(factorize_array)
#   896/848    0.002    0.000    0.003    0.000 spines.py:346(get_spine_transform)
#       669    0.001    0.000    0.003    0.000 lines.py:1158(set_linestyle)
#       676    0.001    0.000    0.004    0.000 _stride_tricks_impl.py:514(broadcast_arrays)
# 4559/4558    0.001    0.000    0.011    0.000 transforms.py:1783(transform)
#       676    0.001    0.000    0.002    0.000 _stride_tricks_impl.py:446(_broadcast_shape)
# 3642/3074    0.001    0.000    0.107    0.000 artist.py:1226(_internal_update)
#       283    0.001    0.000    0.012    0.000 patches.py:800(get_patch_transform)
#      1414    0.001    0.000    0.004    0.000 transforms.py:2342(__init__)
# 11539/11527    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#     16776    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#       113    0.001    0.000    0.004    0.000 ticker.py:819(_set_format)
#       733    0.001    0.000    0.006    0.000 axis.py:406(update_position)
#      3953    0.001    0.000    0.006    0.000 {method 'max' of 'numpy.ndarray' objects}
#       498    0.001    0.000    0.004    0.000 path.py:279(__deepcopy__)
#      1698    0.001    0.000    0.006    0.000 transforms.py:2499(composite_transform_factory)
#       868    0.001    0.000    0.001    0.000 {built-in method builtins.round}
#      2956    0.001    0.000    0.003    0.000 cbook.py:1347(_to_unmasked_float_array)
#      6365    0.001    0.000    0.001    0.000 enum.py:1146(__new__)
#      1219    0.001    0.000    0.002    0.000 generic.py:6208(__setattr__)
#      1039    0.001    0.000    0.002    0.000 generic.py:258(__init__)
#       279    0.001    0.000    0.064    0.000 frame.py:4337(__getitem__)
#      8946    0.001    0.000    0.001    0.000 transforms.py:1927(get_matrix)
#      3288    0.001    0.000    0.016    0.000 font_manager.py:711(__eq__)
#       874    0.001    0.000    0.019    0.000 artist.py:1243(_cm_set)
#      2645    0.001    0.000    0.002    0.000 figure.py:65(_stale_figure_callback)
#       665    0.001    0.000    0.003    0.000 transforms.py:1778(__eq__)
#       780    0.001    0.000    0.002    0.000 array.py:310(__init__)
#       286    0.001    0.000    0.003    0.000 managers.py:1205(iget)
#       840    0.001    0.000    0.002    0.000 base.py:652(_simple_new)
#       124    0.001    0.000    0.103    0.001 axis.py:1328(_get_ticklabel_bboxes)
#       525    0.001    0.000    0.013    0.000 font_manager.py:1363(_find_fonts_by_props)
#      3062    0.001    0.000    0.006    0.000 {method 'min' of 'numpy.ndarray' objects}
#        30    0.001    0.000    0.003    0.000 __init__.py:361(namedtuple)
#      1681    0.001    0.000    0.007    0.000 transforms.py:1996(rotate_deg)
#       240    0.001    0.000    0.002    0.000 _methods.py:96(_clip)
#       875    0.001    0.000    0.007    0.000 path.py:99(__init__)
#       525    0.001    0.000    0.018    0.000 backend_agg.py:248(_prepare_font)
#      4536    0.001    0.000    0.001    0.000 text.py:1275(set_text)
#       2/1    0.001    0.001    8.323    8.323 {built-in method builtins.exec}
#       388    0.001    0.000    0.012    0.000 ticker.py:214(format_ticks)
#       287    0.001    0.000    0.012    0.000 string_arrow.py:317(astype)
#      3318    0.001    0.000    0.003    0.000 font_manager.py:1349(<genexpr>)
#      1081    0.001    0.000    0.005    0.000 markers.py:250(_recache)
#       272    0.001    0.000    0.002    0.000 take.py:118(_take_nd_ndarray)
#       618    0.001    0.000    0.001    0.000 {built-in method numpy.zeros}
#       204    0.001    0.000    0.008    0.000 series.py:369(__init__)
#       577    0.001    0.000    0.013    0.000 text.py:194(update)
#      2848    0.001    0.000    0.002    0.000 __init__.py:330(_compile)
#       144    0.001    0.000    0.011    0.000 transforms.py:642(union)
#       132    0.001    0.000    0.014    0.000 patches.py:583(_draw_paths_with_artist_properties)
#      1678    0.001    0.000    0.016    0.000 transforms.py:2409(transform_affine)
#      1853    0.001    0.000    0.002    0.000 string_.py:236(__eq__)
#       803    0.001    0.000    0.010    0.000 font_manager.py:556(wrapper)
#       287    0.001    0.000    0.005    0.000 core.py:2872(__new__)
#      1541    0.001    0.000    0.014    0.000 transforms.py:796(from_bounds)
#       199    0.001    0.000    0.011    0.000 base.py:3798(_get_indexer)
#       319    0.001    0.000    0.001    0.000 array.py:819(__iter__)
#       517    0.001    0.000    0.037    0.000 text.py:104(__init__)
#       204    0.001    0.000    0.009    0.000 base.py:1228(take)
#      1031    0.001    0.000    0.004    0.000 transforms.py:1833(frozen)
#       229    0.001    0.000    0.008    0.000 array.py:1539(take)
#      4171    0.001    0.000    0.001    0.000 enum.py:187(__get__)
#      1579    0.001    0.000    0.038    0.000 markers.py:220(__init__)
#       234    0.001    0.000    0.001    0.000 ticker.py:1984(scale_range)
#      1293    0.001    0.000    0.005    0.000 lines.py:662(set_data)
#      1580    0.001    0.000    0.004    0.000 artist.py:738(set_figure)
#       256    0.001    0.000    0.005    0.000 transforms.py:461(transformed)
#       272    0.001    0.000    0.006    0.000 managers.py:396(apply)
#       215    0.001    0.000    0.028    0.000 base.py:3656(get_indexer)
#      1832    0.001    0.000    0.001    0.000 text.py:687(_get_wrapped_text)
#      1848    0.001    0.000    0.009    0.000 fromnumeric.py:207(reshape)
#      2323    0.001    0.000    0.001    0.000 artist.py:448(get_transform)
#      1579    0.001    0.000    0.002    0.000 markers.py:275(_set_fillstyle)
#       271    0.001    0.000    0.007    0.000 transforms.py:1419(__sub__)
#       875    0.001    0.000    0.002    0.000 path.py:202(_update_values)
#      1225    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#      3953    0.001    0.000    0.005    0.000 _methods.py:39(_amax)
#       114    0.001    0.000    0.001    0.000 socket.py:623(send)
#      9427    0.001    0.000    0.001    0.000 {built-in method builtins.callable}
#      1933    0.001    0.000    0.005    0.000 fromnumeric.py:3149(min)
#        20    0.001    0.000    0.001    0.000 density_preparation.py:124(build_particle_csr)
#       612    0.001    0.000    0.003    0.000 fromnumeric.py:86(_wrapreduction_any_all)
#       121    0.001    0.000    0.081    0.001 axis.py:428(__init__)
#      1752    0.001    0.000    0.002    0.000 font_manager.py:784(set_family)
#       144    0.001    0.000    0.010    0.000 axis.py:2810(get_tick_space)
#       934    0.001    0.000    0.002    0.000 text.py:901(get_unitless_position)
#      1195    0.001    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       249    0.001    0.000    0.002    0.000 string_.py:197(__init__)
#        20    0.001    0.000    0.001    0.000 {method 'union' of 'set' objects}
#       498    0.001    0.000    0.032    0.000 lines.py:1352(update_from)
#       287    0.001    0.000    0.014    0.000 base.py:5127(_get_engine_target)
#        62    0.001    0.000    0.469    0.008 axis.py:1396(draw)
#      1959    0.001    0.000    0.004    0.000 fromnumeric.py:3011(max)
#       451    0.001    0.000    0.002    0.000 transforms.py:2752(__init__)
#       424    0.001    0.000    0.002    0.000 _py_warnings.py:320(_add_filter)
#      3062    0.001    0.000    0.005    0.000 _methods.py:43(_amin)
#        62    0.001    0.000    0.031    0.001 spines.py:142(get_window_extent)
#     10480    0.001    0.000    0.001    0.000 font_manager.py:717(get_family)
#      2824    0.001    0.000    0.003    0.000 __init__.py:174(search)
#      1632    0.001    0.000    0.006    0.000 transforms.py:1341(__add__)
#       491    0.001    0.000    0.001    0.000 {built-in method numpy.arange}
#      1399    0.001    0.000    0.003    0.000 artist.py:435(set_transform)
#      1038    0.001    0.000    0.004    0.000 backend_bases.py:848(set_clip_path)
#        46    0.001    0.000    0.001    0.000 _arraysetops_impl.py:806(_isin)
#   325/169    0.001    0.000    0.003    0.000 units.py:164(get_converter)
#       158    0.001    0.000    0.017    0.000 core.py:3133(__array_wrap__)
#      5204    0.001    0.000    0.001    0.000 _base.py:891(<genexpr>)
#      1689    0.001    0.000    0.001    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#      1300    0.001    0.000    0.004    0.000 colors.py:224(is_color_like)
#       988    0.001    0.000    0.001    0.000 range.py:236(_simple_new)
#      8686    0.001    0.000    0.001    0.000 transforms.py:1040(get_points)
#      1129    0.001    0.000    0.001    0.000 text.py:1259(set_verticalalignment)
#       287    0.001    0.000    0.005    0.000 base.py:804(astype)
#      9955    0.001    0.000    0.001    0.000 font_manager.py:768(get_file)
#      2573    0.001    0.000    0.002    0.000 artist.py:268(convert_xunits)
#      1895    0.001    0.000    0.002    0.000 scale.py:132(get_transform)
#      1300    0.001    0.000    0.005    0.000 colors.py:243(_check_color_like)
#       120    0.001    0.000    0.006    0.000 axis.py:302(_apply_params)
# 1260/1212    0.001    0.000    0.012    0.000 _base.py:901(viewLim)
#      4978    0.001    0.000    0.001    0.000 {method 'count' of 'str' objects}
#     74/66    0.001    0.000    0.007    0.000 axis.py:1195(_set_lim)
#      1832    0.001    0.000    0.001    0.000 text.py:284(get_rotation)
#        91    0.001    0.000    0.062    0.001 axis.py:367(__init__)
#     10721    0.001    0.000    0.001    0.000 font_manager.py:762(get_size)
#       113    0.001    0.000    0.002    0.000 ticker.py:746(_compute_offset)
#        10    0.001    0.000    0.051    0.005 assimilate.py:101(compute_partial_kalman_gain)
#      9955    0.001    0.000    0.001    0.000 font_manager.py:926(get_math_fontfamily)
#       963    0.001    0.000    0.003    0.000 common.py:142(is_object_dtype)
#       399    0.001    0.000    0.001    0.000 {method 'round' of 'numpy.ndarray' objects}
#      1050    0.001    0.000    0.003    0.000 base.py:1033(view)
#      2586    0.001    0.000    0.001    0.000 cbook.py:1860(_str_equal)
#        62    0.001    0.000    0.004    0.000 base.py:2457(is_unique)
#       525    0.001    0.000    0.001    0.000 {built-in method matplotlib.ft2font.clear}
#       594    0.001    0.000    0.004    0.000 common.py:1245(is_numeric_dtype)
#       525    0.001    0.000    0.001    0.000 backend_agg.py:41(get_hinting_flag)
#      2245    0.001    0.000    0.001    0.000 {method 'wrap' of 'numpy._core._multiarray_umath._array_converter' objects}
#      2221    0.001    0.000    0.001    0.000 {method 'as_arrays' of 'numpy._core._multiarray_umath._array_converter' objects}
#       424    0.001    0.000    0.001    0.000 _py_warnings.py:639(__enter__)
#      9955    0.001    0.000    0.001    0.000 font_manager.py:733(get_style)
#       568    0.001    0.000    0.011    0.000 text.py:1316(set_fontproperties)
#       771    0.001    0.000    0.001    0.000 core.py:1352(_replace_dtype_fields)
#       102    0.001    0.000    0.043    0.000 base.py:6288(_get_indexer_strict)
#       586    0.001    0.000    0.005    0.000 generic.py:6191(__getattr__)
#      9955    0.001    0.000    0.001    0.000 font_manager.py:739(get_variant)
#       803    0.001    0.000    0.002    0.000 font_manager.py:798(set_style)
#       637    0.001    0.000    0.003    0.000 text.py:995(set_color)
#       124    0.001    0.000    0.008    0.000 managers.py:792(reindex_indexer)
#       813    0.001    0.000    0.002    0.000 ticker.py:610(__call__)
#      4219    0.001    0.000    0.001    0.000 {built-in method builtins.delattr}
#       541    0.001    0.000    0.002    0.000 transforms.py:1613(transform_path_non_affine)
#       817    0.001    0.000    0.020    0.000 base.py:7919(ensure_index)
#      2636    0.001    0.000    0.001    0.000 text.py:1216(set_y)
#      6546    0.001    0.000    0.001    0.000 artist.py:972(get_agg_filter)
#      6415    0.001    0.000    0.001    0.000 artist.py:853(get_visible)
#       190    0.001    0.000    0.011    0.000 artist.py:784(set_clip_path)
#      1690    0.001    0.000    0.002    0.000 transforms.py:2413(transform_non_affine)
#       445    0.001    0.000    0.003    0.000 transforms.py:2767(_revalidate)
#      1516    0.001    0.000    0.001    0.000 inference.py:387(is_hashable)
#   958/952    0.001    0.000    0.010    0.000 axis.py:2345(getter)
#       101    0.001    0.000    0.006    0.000 patches.py:48(__init__)
#        88    0.001    0.000    0.006    0.000 base.py:849(_engine)
#       316    0.001    0.000    0.002    0.000 common.py:239(asarray_tuplesafe)
#       117    0.001    0.000    0.001    0.000 utils.py:241(maybe_convert_indices)
#      1662    0.001    0.000    0.001    0.000 lines.py:89(_scale_dashes)
#      2916    0.001    0.000    0.001    0.000 {method 'search' of 're.Pattern' objects}
#       316    0.001    0.000    0.001    0.000 axis.py:711(_get_axis_name)
#      9955    0.001    0.000    0.001    0.000 font_manager.py:745(get_weight)
#      9955    0.001    0.000    0.001    0.000 font_manager.py:754(get_stretch)
#      6546    0.001    0.000    0.001    0.000 artist.py:945(get_rasterized)
#       854    0.001    0.000    0.001    0.000 lines.py:982(_get_markerfacecolor)
#      1212    0.001    0.000    0.001    0.000 common.py:1624(_get_dtype)
#      1038    0.001    0.000    0.008    0.000 backend_bases.py:604(new_gc)
#        97    0.001    0.000    0.001    0.000 cast.py:127(maybe_convert_platform)
#       113    0.001    0.000    0.002    0.000 ticker.py:785(_set_order_of_magnitude)
#      1109    0.001    0.000    0.001    0.000 text.py:1010(set_horizontalalignment)
#      1017    0.001    0.000    0.001    0.000 path.py:162(_fast_from_codes_and_verts)
#      2609    0.001    0.000    0.002    0.000 artist.py:280(convert_yunits)
#       781    0.001    0.000    0.002    0.000 transforms.py:300(xmin)
#       526    0.001    0.000    0.001    0.000 getlimits.py:412(__init__)
#       780    0.001    0.000    0.001    0.000 dtypes.py:2193(__init__)
#      1500    0.001    0.000    0.002    0.000 artist.py:1055(set_visible)
#        90    0.001    0.000    0.007    0.000 axis.py:2580(get_tick_space)
#       318    0.001    0.000    0.003    0.000 base.py:5334(__contains__)
#       234    0.001    0.000    0.004    0.000 axis.py:1594(_get_tick_label_size)
#       128    0.001    0.000    0.014    0.000 generic.py:4010(take)
#      2705    0.001    0.000    0.001    0.000 __init__.py:167(<genexpr>)
#      1038    0.001    0.000    0.004    0.000 artist.py:935(_set_gc_clip)
#        33    0.001    0.000    0.001    0.000 _methods.py:148(_var)
#         1    0.001    0.001    0.146    0.146 Metrics.py:14(__init__)
#       155    0.001    0.000    0.001    0.000 bezier.py:208(__call__)
#      2757    0.001    0.000    0.001    0.000 transforms.py:196(<lambda>)
#       657    0.001    0.000    0.001    0.000 lines.py:1423(set_dash_capstyle)
#        44    0.001    0.000    0.001    0.000 {built-in method _operator.ge}
#       106    0.001    0.000    0.005    0.000 indexing.py:1058(_getitem_lowerdim)
#      4536    0.001    0.000    0.001    0.000 {method 'copy' of 'list' objects}
#       529    0.001    0.000    0.001    0.000 numerictypes.py:475(issubdtype)
#        87    0.001    0.000    0.001    0.000 core.py:3510(__setmask__)
#       155    0.001    0.000    0.001    0.000 bezier.py:199(__init__)
#       233    0.001    0.000    0.017    0.000 indexing.py:1192(__getitem__)
#       164    0.001    0.000    0.038    0.000 axis.py:1606(_copy_tick_props)
#       812    0.001    0.000    0.002    0.000 transforms.py:315(ymax)
#       570    0.001    0.000    0.001    0.000 indexing.py:2780(check_dict_or_set_indexers)
#      1324    0.001    0.000    0.001    0.000 {built-in method _abc._abc_subclasscheck}
#       329    0.001    0.000    0.002    0.000 core.py:1463(getmaskarray)
#       813    0.001    0.000    0.001    0.000 ticker.py:552(_format_maybe_minus_and_locale)
#      1060    0.001    0.000    0.003    0.000 axis.py:293(_set_artist_props)
#      2122    0.001    0.000    0.001    0.000 text.py:1205(set_x)
#      1063    0.001    0.000    0.003    0.000 common.py:1600(_is_dtype)
#       781    0.001    0.000    0.002    0.000 transforms.py:310(xmax)
#      3172    0.001    0.000    0.001    0.000 {built-in method builtins.abs}
#       251    0.001    0.000    0.001    0.000 transforms.py:366(bounds)
#      1326    0.001    0.000    0.001    0.000 font_manager.py:876(set_size)
#        44    0.001    0.000    0.001    0.000 {built-in method _operator.lt}
#       657    0.001    0.000    0.001    0.000 lines.py:1143(set_linewidth)
#       673    0.001    0.000    0.001    0.000 text.py:1227(set_rotation)
#      2301    0.001    0.000    0.002    0.000 transforms.py:2121(transform)
#       295    0.001    0.000    0.004    0.000 config.py:650(_select_options)
#       792    0.001    0.000    0.002    0.000 transforms.py:305(ymin)
#       788    0.001    0.000    0.001    0.000 lines.py:33(_get_dash_pattern)
#        38    0.001    0.000    0.001    0.000 colors.py:745(_get_rgba_and_mask)
#        31    0.001    0.000    0.008    0.000 _base.py:2497(_update_patch_limits)
#       418    0.001    0.000    0.014    0.000 patches.py:307(get_transform)
#       212    0.001    0.000    0.144    0.001 axis.py:1585(_get_tick)
#       803    0.001    0.000    0.001    0.000 font_manager.py:811(set_variant)
#       863    0.001    0.000    0.002    0.000 range.py:620(_view)
#      1842    0.001    0.000    0.001    0.000 base.py:837(_reset_identity)
#       574    0.001    0.000    0.001    0.000 string_.py:232(__repr__)
#       445    0.000    0.000    0.003    0.000 lines.py:731(_transform_path)
#      1447    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       213    0.000    0.000    0.008    0.000 indexing.py:1740(_getitem_axis)
#      3324    0.000    0.000    0.000    0.000 __init__.py:79(<genexpr>)
#      1058    0.000    0.000    0.001    0.000 cbook.py:1871(_str_lower_equal)
#       657    0.000    0.000    0.001    0.000 lines.py:1085(set_drawstyle)
#       826    0.000    0.000    0.000    0.000 {method '__deepcopy__' of 'numpy.ndarray' objects}
#      1701    0.000    0.000    0.002    0.000 axis.py:753(get_transform)
#       662    0.000    0.000    0.001    0.000 _base.py:605(_axis_map)
#       493    0.000    0.000    0.003    0.000 string_arrow.py:161(_from_pyarrow_array)
#       234    0.000    0.000    0.150    0.001 axis.py:1644(get_major_ticks)
#       370    0.000    0.000    0.003    0.000 base.py:5446(_can_hold_identifiers_and_holds_name)
#       498    0.000    0.000    0.001    0.000 transforms.py:128(__getstate__)
#       424    0.000    0.000    0.001    0.000 _py_warnings.py:668(__exit__)
#     19/18    0.000    0.000    0.006    0.000 _base.py:2962(autoscale_view)
#       350    0.000    0.000    0.001    0.000 base.py:931(__iter__)
#       234    0.000    0.000    0.031    0.000 ticker.py:2232(tick_values)
#      1801    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       102    0.000    0.000    0.001    0.000 __init__.py:416(by_key)
#      1361    0.000    0.000    0.001    0.000 transforms.py:2209(<lambda>)
#       424    0.000    0.000    0.005    0.000 lines.py:1203(set_marker)
#   271/251    0.000    0.000    0.005    0.000 missing.py:180(_isna)
#       436    0.000    0.000    0.001    0.000 transforms.py:2667(__init__)
#       525    0.000    0.000    0.000    0.000 {built-in method matplotlib.ft2font.set_size}
#      1096    0.000    0.000    0.006    0.000 font_manager.py:677(_from_any)
#       588    0.000    0.000    0.002    0.000 common.py:105(is_bool_indexer)
#        12    0.000    0.000    0.058    0.005 _base.py:1313(__clear)
#         3    0.000    0.000    0.073    0.024 relational.py:229(plot)
#  1113/605    0.000    0.000    0.002    0.000 _base.py:1046(get_yaxis_transform)
#       785    0.000    0.000    0.002    0.000 generic.py:294(_from_mgr)
#       893    0.000    0.000    0.005    0.000 {method 'all' of 'numpy.ndarray' objects}
#      4902    0.000    0.000    0.000    0.000 figure.py:2854(_get_dpi)
#      1281    0.000    0.000    0.005    0.000 _methods.py:64(_all)
#       328    0.000    0.000    0.005    0.000 text.py:342(update_from)
#      4014    0.000    0.000    0.000    0.000 figure.py:232(get_figure)
#     38/36    0.000    0.000    0.005    0.000 _base.py:3021(handle_single_axis)
#       565    0.000    0.000    0.002    0.000 text.py:1040(set_linespacing)
#        37    0.000    0.000    0.012    0.000 _base.py:1472(variable_type)
#        58    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.update_path_extents}
#      4555    0.000    0.000    0.000    0.000 artist.py:1140(sticky_edges)
#       313    0.000    0.000    0.003    0.000 base.py:5384(__getitem__)
#       370    0.000    0.000    0.010    0.000 frame.py:4292(_ixs)
#       369    0.000    0.000    0.001    0.000 managers.py:215(shape)
#       298    0.000    0.000    0.001    0.000 transforms.py:2576(__init__)
#       540    0.000    0.000    0.001    0.000 utils.py:441(check_array_indexer)
#      1902    0.000    0.000    0.001    0.000 transforms.py:2249(get_affine)
#       696    0.000    0.000    0.001    0.000 construction.py:718(_sanitize_ndim)
#       307    0.000    0.000    0.002    0.000 blocks.py:639(copy)
#       286    0.000    0.000    0.005    0.000 frame.py:4954(_box_col_values)
#       186    0.000    0.000    0.002    0.000 spines.py:235(_adjust_location)
#      1381    0.000    0.000    0.001    0.000 managers.py:2183(internal_values)
#       159    0.000    0.000    0.003    0.000 colors.py:2214(process_value)
#       116    0.000    0.000    0.024    0.000 axis.py:946(set_tick_params)
#      1039    0.000    0.000    0.000    0.000 flags.py:63(__init__)
#      2041    0.000    0.000    0.000    0.000 artist.py:297(axes)
#      1629    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#       343    0.000    0.000    0.001    0.000 cbook.py:2368(_unpack_to_numpy)
#      2682    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        10    0.000    0.000    3.226    0.323 assimilate.py:199(assimilate)
#       234    0.000    0.000    0.035    0.000 ticker.py:2228(__call__)
#        45    0.000    0.000    0.004    0.000 colors.py:2254(__call__)
#       540    0.000    0.000    0.001    0.000 managers.py:223(blknos)
#       154    0.000    0.000    0.001    0.000 construction.py:999(convert)
#        25    0.000    0.000    0.001    0.000 socket.py:771(recv_multipart)
#      2240    0.000    0.000    0.001    0.000 string_arrow.py:184(__len__)
#      3951    0.000    0.000    0.000    0.000 text.py:915(get_text)
#        71    0.000    0.000    0.003    0.000 path.py:627(get_extents)
#       204    0.000    0.000    0.020    0.000 patches.py:633(draw)
#        31    0.000    0.000    0.523    0.017 _base.py:3161(draw)
#       388    0.000    0.000    0.001    0.000 {method 'all' of 'numpy.generic' objects}
#       329    0.000    0.000    0.002    0.000 patches.py:792(_convert_units)
#      1571    0.000    0.000    0.001    0.000 backend_bases.py:883(set_foreground)
#       578    0.000    0.000    0.001    0.000 transforms.py:2028(translate)
#        92    0.000    0.000    0.001    0.000 _base.py:4453(get_children)
#       295    0.000    0.000    0.005    0.000 config.py:127(_get_single_key)
#       663    0.000    0.000    0.003    0.000 lines.py:1073(set_color)
#       315    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#   843/455    0.000    0.000    0.002    0.000 _base.py:964(get_xaxis_transform)
#   153/152    0.000    0.000    0.002    0.000 transforms.py:1109(get_points)
#      1998    0.000    0.000    0.001    0.000 copy.py:233(<genexpr>)
#       296    0.000    0.000    0.003    0.000 take.py:57(take_nd)
#       569    0.000    0.000    0.001    0.000 units.py:56(_is_natively_supported)
#        22    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#      2124    0.000    0.000    0.002    0.000 base.py:918(__len__)
#      1991    0.000    0.000    0.001    0.000 range.py:1266(__len__)
#       445    0.000    0.000    0.001    0.000 markers.py:266(__bool__)
#       759    0.000    0.000    0.000    0.000 transforms.py:339(intervaly)
#     39/21    0.000    0.000    0.007    0.000 offsetbox.py:487(_get_bbox_and_child_offsets)
#       468    0.000    0.000    0.002    0.000 transforms.py:786(unit)
#      1845    0.000    0.000    0.001    0.000 __init__.py:1354(_val_or_rc)
#       370    0.000    0.000    0.002    0.000 frame.py:686(_constructor_sliced_from_mgr)
#       266    0.000    0.000    0.000    0.000 cast.py:451(maybe_promote)
#       133    0.000    0.000    0.001    0.000 colors.py:419(to_rgba_array)
#       345    0.000    0.000    0.001    0.000 blocks.py:2258(new_block)
#       504    0.000    0.000    0.001    0.000 common.py:652(condition)
#       657    0.000    0.000    0.001    0.000 lines.py:1375(set_dash_joinstyle)
#      2549    0.000    0.000    0.000    0.000 {built-in method math.radians}
#       190    0.000    0.000    0.001    0.000 utils.py:416(getitem_returns_view)
#      3709    0.000    0.000    0.000    0.000 path.py:211(vertices)
#       376    0.000    0.000    0.001    0.000 getlimits.py:178(__new__)
#       253    0.000    0.000    0.001    0.000 base.py:3601(get_loc)
#      1038    0.000    0.000    0.000    0.000 backend_bases.py:945(get_hatch_path)
#       225    0.000    0.000    0.000    0.000 base.py:2529(inferred_type)
#       771    0.000    0.000    0.000    0.000 core.py:1320(_replace_dtype_fields_recursive)
#       573    0.000    0.000    0.000    0.000 generic.py:535(_get_axis)
#        12    0.000    0.000    0.003    0.000 axis.py:2027(set_ticklabels)
#       332    0.000    0.000    0.001    0.000 base.py:5584(equals)
#        52    0.000    0.000    0.004    0.000 spines.py:35(__init__)
#       174    0.000    0.000    0.005    0.000 managers.py:718(copy)
#        50    0.000    0.000    0.014    0.000 frame.py:702(__init__)
# 1438/1427    0.000    0.000    0.001    0.000 transforms.py:2591(get_matrix)
#        31    0.000    0.000    0.001    0.000 managers.py:2380(_form_blocks)
#      1720    0.000    0.000    0.000    0.000 cbook.py:152(__init__)
#       663    0.000    0.000    0.002    0.000 lines.py:752(set_transform)
#      1005    0.000    0.000    0.000    0.000 backend_bases.py:828(set_antialiased)
#      1050    0.000    0.000    0.000    0.000 font_manager.py:1610(<genexpr>)
#        50    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#      1381    0.000    0.000    0.001    0.000 series.py:789(_values)
#       518    0.000    0.000    0.001    0.000 artist.py:1124(set_zorder)
#      2115    0.000    0.000    0.000    0.000 {built-in method math.cos}
#        12    0.000    0.000    0.076    0.006 _base.py:615(__init__)
#       593    0.000    0.000    0.000    0.000 text.py:298(set_rotation_mode)
#         7    0.000    0.000    0.000    0.000 {built-in method _io.open}
#       211    0.000    0.000    0.001    0.000 transforms.py:1088(__init__)
#       249    0.000    0.000    0.000    0.000 string_.py:312(construct_array_type)
#       411    0.000    0.000    0.002    0.000 _py_warnings.py:294(simplefilter)
#       970    0.000    0.000    0.000    0.000 numeric.py:2476(<genexpr>)
#       968    0.000    0.000    0.001    0.000 transforms.py:2217(transform_non_affine)
#      38/7    0.000    0.000    0.523    0.075 image.py:116(_draw_list_compositing_images)
#       498    0.000    0.000    0.005    0.000 copy.py:206(_deepcopy_method)
#      3694    0.000    0.000    0.000    0.000 text.py:1345(get_usetex)
#       469    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        30    0.000    0.000    0.012    0.000 frame.py:1591(itertuples)
#      1134    0.000    0.000    0.001    0.000 transforms.py:1356(_iter_break_from_left_to_right)
#       114    0.000    0.000    0.001    0.000 cbook.py:293(connect)
#       403    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1401(_handle_fromlist)
#      1058    0.000    0.000    0.001    0.000 numerictypes.py:293(issubclass_)
#       165    0.000    0.000    0.001    0.000 managers.py:2032(from_array)
#        95    0.000    0.000    0.003    0.000 _base.py:2624(_process_unit_info)
#      1601    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        62    0.000    0.000    0.073    0.001 axis.py:2223(_get_tick_boxes_siblings)
#       813    0.000    0.000    0.001    0.000 ticker.py:246(fix_minus)
#       311    0.000    0.000    0.001    0.000 _utils.py:27(to_numpy_dtype_inference)
#        74    0.000    0.000    0.001    0.000 colors.py:325(_to_rgba_no_colorcycle)
#       790    0.000    0.000    0.001    0.000 shape_base.py:206(_arrays_for_stack_dispatcher)
#       839    0.000    0.000    0.000    0.000 flags.py:99(allows_duplicate_labels)
#        27    0.000    0.000    0.000    0.000 function_base.py:27(linspace)
#       657    0.000    0.000    0.001    0.000 lines.py:1439(set_solid_capstyle)
#       568    0.000    0.000    0.000    0.000 spines.py:572(__getitem__)
#       157    0.000    0.000    0.001    0.000 series.py:844(__array__)
#        84    0.000    0.000    0.001    0.000 managers.py:1132(fast_xs)
#       754    0.000    0.000    0.000    0.000 common.py:377(apply_if_callable)
#       333    0.000    0.000    0.001    0.000 blocks.py:2187(maybe_coerce_values)
#     24/16    0.000    0.000    0.001    0.000 gridspec.py:144(get_grid_positions)
#      3658    0.000    0.000    0.000    0.000 string_arrow.py:248(dtype)
# ...
#         8    0.000    0.000    0.000    0.000 _base.py:835(get_subplotspec)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         3    0.000    0.000    0.000    0.000 _util.py:12(is_path)
#         3    0.000    0.000    0.000    0.000 contextlib.py:552(_push_exit_callback)
#         6    0.000    0.000    0.000    0.000 ops.py:887(<genexpr>)
#         4    0.000    0.000    0.000    0.000 concat.py:44(_is_nonempty)
#        18    0.000    0.000    0.000    0.000 artist.py:457(get_children)
#         1    0.000    0.000    0.000    0.000 counting.py:116(__post_init__)
#         1    0.000    0.000    0.000    0.000 arraylike.py:196(__sub__)
#         1    0.000    0.000    0.000    0.000 threading.py:322(_release_save)
#         3    0.000    0.000    0.000    0.000 utils.py:803(_deprecate_ci)
#         7    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        12    0.000    0.000    0.000    0.000 types.py:202(is_floating)
#         4    0.000    0.000    0.000    0.000 collections.py:1696(set_color)
#        12    0.000    0.000    0.000    0.000 types.py:369(is_decimal)
#         3    0.000    0.000    0.000    0.000 Image.py:2605(_attach_default_encoderinfo)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         3    0.000    0.000    0.000    0.000 colors.py:840(set_bad)
#         9    0.000    0.000    0.000    0.000 _arraysetops_impl.py:661(_intersect1d_dispatcher)
#        14    0.000    0.000    0.000    0.000 ticker.py:326(get_offset)
#        11    0.000    0.000    0.000    0.000 hmac.py:172(_current)
#        14    0.000    0.000    0.000    0.000 multiarray.py:982(ravel_multi_index)
#         2    0.000    0.000    0.000    0.000 concat.py:98(<genexpr>)
#         8    0.000    0.000    0.000    0.000 ticker.py:314(__init__)
#        11    0.000    0.000    0.000    0.000 numeric.py:675(_flatnonzero_dispatcher)
#         3    0.000    0.000    0.000    0.000 {method 'cleanup' of 'ImagingEncoder' objects}
#         2    0.000    0.000    0.000    0.000 threading.py:316(__exit__)
#         2    0.000    0.000    0.000    0.000 threading.py:313(__enter__)
#         2    0.000    0.000    0.000    0.000 multi.py:3435(_get_loc_single_level_index)
#         7    0.000    0.000    0.000    0.000 _validators.py:476(check_dtype_backend)
#         6    0.000    0.000    0.000    0.000 {built-in method sys.exception}
#         4    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.OrderedDict' objects}
#         4    0.000    0.000    0.000    0.000 base.py:2993(_validate_sort_keyword)
#         1    0.000    0.000    0.000    0.000 expressions.py:68(_evaluate_standard)
#         6    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 format.py:626(_is_in_terminal)
#         2    0.000    0.000    0.000    0.000 __init__.py:276(_from_parsed_string)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        12    0.000    0.000    0.000    0.000 Image.py:573(readonly)
#         3    0.000    0.000    0.000    0.000 {built-in method sys.is_finalizing}
#         1    0.000    0.000    0.000    0.000 distributions.py:129(has_xy_data)
#         2    0.000    0.000    0.000    0.000 inference.py:106(is_file_like)
#         3    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 axis.py:1636(get_major_formatter)
#         9    0.000    0.000    0.000    0.000 lines.py:908(get_color)
#         1    0.000    0.000    0.000    0.000 series.py:1910(_set_name)
#         3    0.000    0.000    0.000    0.000 PngImagePlugin.py:292(add)
#         2    0.000    0.000    0.000    0.000 replace.py:32(should_use_regex)
#         4    0.000    0.000    0.000    0.000 {built-in method math.copysign}
#         6    0.000    0.000    0.000    0.000 legend.py:713(_get_loc)
#         6    0.000    0.000    0.000    0.000 _nanfunctions_impl.py:1220(_nanpercentile_dispatcher)
#         2    0.000    0.000    0.000    0.000 csvs.py:121(_initialize_index_label)
#         2    0.000    0.000    0.000    0.000 csvs.py:174(_initialize_chunksize)
#         1    0.000    0.000    0.000    0.000 nanops.py:336(_na_ok_dtype)
#         1    0.000    0.000    0.000    0.000 inspect.py:2862(kwargs)
#         2    0.000    0.000    0.000    0.000 categorical.py:3055(recode_for_categories)
#        10    0.000    0.000    0.000    0.000 _twodim_base_impl.py:254(_diag_dispatcher)
#         2    0.000    0.000    0.000    0.000 shutil.py:277(_stat)
#         2    0.000    0.000    0.000    0.000 rcsetup.py:375(validate_fontsize_None)
#         2    0.000    0.000    0.000    0.000 base.py:762(_shallow_copy)
#        11    0.000    0.000    0.000    0.000 frame.py:663(_constructor)
#         3    0.000    0.000    0.000    0.000 contextlib.py:475(_create_exit_wrapper)
#         9    0.000    0.000    0.000    0.000 backend_bases.py:628(start_rasterizing)
#         7    0.000    0.000    0.000    0.000 backend_bases.py:1868(draw)
#         1    0.000    0.000    0.000    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#        12    0.000    0.000    0.000    0.000 Image.py:565(mode)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#         5    0.000    0.000    0.000    0.000 utils.py:750(_check_argument)
#         7    0.000    0.000    0.000    0.000 backend_bases.py:1182(__init__)
#         4    0.000    0.000    0.000    0.000 common.py:860(<lambda>)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.fstat}
#         1    0.000    0.000    0.000    0.000 expressions.py:227(evaluate)
#         1    0.000    0.000    0.000    0.000 nanops.py:189(_get_fill_value)
#        13    0.000    0.000    0.000    0.000 range.py:343(stop)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_io._IOBase' objects}
#         4    0.000    0.000    0.000    0.000 collections.py:1681(_get_default_antialiased)
#         6    0.000    0.000    0.000    0.000 widgets.py:38(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#         1    0.000    0.000    0.000    0.000 missing.py:131(dispatch_fill_zeros)
#         6    0.000    0.000    0.000    0.000 backend_bases.py:1682(<lambda>)
#         3    0.000    0.000    0.000    0.000 {method 'islower' of 'bytes' objects}
#         3    0.000    0.000    0.000    0.000 legend.py:1086(set_bbox_to_anchor)
#         3    0.000    0.000    0.000    0.000 figure.py:79(__init__)
#         6    0.000    0.000    0.000    0.000 csvs.py:105(float_format)
#         1    0.000    0.000    0.000    0.000 concat.py:191(_is_homogeneous_mgr)
#         4    0.000    0.000    0.000    0.000 axis.py:1632(get_minor_locator)
#         3    0.000    0.000    0.000    0.000 patches.py:4000(set_mutation_scale)
#         9    0.000    0.000    0.000    0.000 legend.py:791(get_default_handler_map)
#         8    0.000    0.000    0.000    0.000 _function_base_impl.py:5045(_meshgrid_dispatcher)
#         2    0.000    0.000    0.000    0.000 cast.py:825(_maybe_infer_dtype_type)
#         9    0.000    0.000    0.000    0.000 backend_bases.py:635(stop_rasterizing)
#         7    0.000    0.000    0.000    0.000 contextlib.py:792(__exit__)
#         7    0.000    0.000    0.000    0.000 _shape_base_impl.py:1195(_tile_dispatcher)
#         6    0.000    0.000    0.000    0.000 csvs.py:101(na_rep)
#         2    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         2    0.000    0.000    0.000    0.000 multi.py:3214(_check_indexing_error)
#         4    0.000    0.000    0.000    0.000 _base.py:848(get_window_extent)
#         7    0.000    0.000    0.000    0.000 range.py:251(_validate_dtype)
#         2    0.000    0.000    0.000    0.000 format.py:526(_initialize_sparsify)
#         3    0.000    0.000    0.000    0.000 ImageFile.py:97(_tilesort)
#         3    0.000    0.000    0.000    0.000 __init__.py:1342(is_interactive)
#         2    0.000    0.000    0.000    0.000 container.py:16(__new__)
#         2    0.000    0.000    0.000    0.000 common.py:535(get_compression_method)
#         1    0.000    0.000    0.000    0.000 common.py:645(fill_missing_names)
#         2    0.000    0.000    0.000    0.000 {method 'index' of 'range' objects}
#         6    0.000    0.000    0.000    0.000 multiarray.py:1135(putmask)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1096(_argsort_dispatcher)
#         2    0.000    0.000    0.000    0.000 printing.py:522(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.OrderedDict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 spines.py:590(__setitem__)
#         7    0.000    0.000    0.000    0.000 contextlib.py:786(__init__)
#         1    0.000    0.000    0.000    0.000 nanops.py:1461(_maybe_arg_null_out)
#         1    0.000    0.000    0.000    0.000 multi.py:1465(dtype)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#        10    0.000    0.000    0.000    0.000 inspect.py:3042(parameters)
#         3    0.000    0.000    0.000    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#         9    0.000    0.000    0.000    0.000 Image.py:561(size)
#         4    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISDIR}
#         7    0.000    0.000    0.000    0.000 indexing.py:1266(_has_valid_setitem_indexer)
#         6    0.000    0.000    0.000    0.000 transforms.py:1792(transform_non_affine)
#         6    0.000    0.000    0.000    0.000 numeric.py:393(_full_like_dispatcher)
#         6    0.000    0.000    0.000    0.000 _function_base_impl.py:133(<lambda>)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:548(_swapaxes_dispatcher)
#         1    0.000    0.000    0.000    0.000 array_ops.py:610(_bool_arith_check)
#         6    0.000    0.000    0.000    0.000 csvs.py:109(decimal)
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 backend_bases.py:2199(get_default_filetype)
#         1    0.000    0.000    0.000    0.000 base.py:33(_check_param_one_of)
#         3    0.000    0.000    0.000    0.000 figure.py:2658(_check_layout_engines_compat)
#         6    0.000    0.000    0.000    0.000 csvs.py:113(header)
#         6    0.000    0.000    0.000    0.000 Image.py:549(im)
#         3    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 artist.py:1088(set_in_layout)
#         7    0.000    0.000    0.000    0.000 contextlib.py:789(__enter__)
#         3    0.000    0.000    0.000    0.000 Image.py:327(preinit)
#         2    0.000    0.000    0.000    0.000 history.py:1100(hold)
#         1    0.000    0.000    0.000    0.000 {method 'capitalize' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of 'sqlite3.Connection' objects}
#         3    0.000    0.000    0.000    0.000 legend.py:1189(set_draggable)
#         1    0.000    0.000    0.000    0.000 {built-in method math.isnan}
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         6    0.000    0.000    0.000    0.000 csvs.py:117(index)
#         1    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 PngImagePlugin.py:289(__init__)
#         2    0.000    0.000    0.000    0.000 inference.py:154(is_re)
#         4    0.000    0.000    0.000    0.000 _function_base_impl.py:5201(_delete_dispatcher)
#         3    0.000    0.000    0.000    0.000 patches.py:3996(get_boxstyle)
#         4    0.000    0.000    0.000    0.000 range.py:559(_should_fallback_to_positional)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 series.py:6753(_align_for_op)
#         3    0.000    0.000    0.000    0.000 backend_bases.py:2736(set_window_title)
#         6    0.000    0.000    0.000    0.000 contextlib.py:568(__enter__)
#         2    0.000    0.000    0.000    0.000 format.py:494(is_truncated_horizontally)
#         1    0.000    0.000    0.000    0.000 events.py:78(cancel)
#         3    0.000    0.000    0.000    0.000 _shape_base_impl.py:733(_array_split_dispatcher)
#         1    0.000    0.000    0.000    0.000 function.py:105(process_skipna)
#         2    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 parse.py:424(_checknetloc)
#         3    0.000    0.000    0.000    0.000 patches.py:2567(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 generic.py:4356(_check_inplace_and_allows_duplicate_labels)
#         2    0.000    0.000    0.000    0.000 format.py:892(__init__)
#         3    0.000    0.000    0.000    0.000 PngImagePlugin.py:1138(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:328(_is_owned)
#         3    0.000    0.000    0.000    0.000 patches.py:4026(get_mutation_aspect)
#         1    0.000    0.000    0.000    0.000 {method 'fileno' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISFIFO}
#         4    0.000    0.000    0.000    0.000 artist.py:307(stale)
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 legend.py:981(get_frame)
#         2    0.000    0.000    0.000    0.000 <frozen codecs>:189(__init__)
#         3    0.000    0.000    0.000    0.000 backend_bases.py:2723(destroy)
#         3    0.000    0.000    0.000    0.000 transforms.py:2141(transform_path_non_affine)
#         2    0.000    0.000    0.000    0.000 format.py:558(_initialize_colspace)
#         2    0.000    0.000    0.000    0.000 format.py:498(is_truncated_vertically)
#         1    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         4    0.000    0.000    0.000    0.000 ticker.py:234(get_offset)
#         3    0.000    0.000    0.000    0.000 patches.py:4011(get_mutation_scale)
#         2    0.000    0.000    0.000    0.000 csvs.py:143(_initialize_quotechar)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         3    0.000    0.000    0.000    0.000 inspect.py:2737(default)
#         1    0.000    0.000    0.000    0.000 patches.py:337(get_facecolor)
#         1    0.000    0.000    0.000    0.000 inspect.py:2831(__init__)
#         1    0.000    0.000    0.000    0.000 function.py:341(validate_minmax_axis)
#         2    0.000    0.000    0.000    0.000 format.py:612(_adjust_max_rows)
#         2    0.000    0.000    0.000    0.000 format.py:531(_initialize_formatters)
#         2    0.000    0.000    0.000    0.000 format.py:851(_validate_float_format)
#         2    0.000    0.000    0.000    0.000 multi.py:2622(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _histograms_impl.py:469(_histogram_bin_edges_dispatcher)
#         1    0.000    0.000    0.000    0.000 managers.py:768(_consolidate_inplace)
#         2    0.000    0.000    0.000    0.000 common.py:142(__enter__)
#         3    0.000    0.000    0.000    0.000 transforms.py:2145(get_affine)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:433(_repeat_dispatcher)
#         1    0.000    0.000    0.000    0.000 _histograms_impl.py:680(_histogram_dispatcher)
#         2    0.000    0.000    0.000    0.000 parse.py:108(_noop)
#         1    0.000    0.000    0.000    0.000 multi.py:2605(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base_events.py:1961(_timer_handle_cancelled)
#         1    0.000    0.000    0.000    0.000 {method 'fileno' of '_io.BufferedWriter' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}

# %% [markdown]
# ## 2. Run a self-assimilation experiment with observation sampled a dispersion model assimilated into another dispersion model

# %%
# First, download the data if it's not present, and prepare it

import xarray as xr
import numpy as np
from datetime import datetime
from dask.diagnostics import ProgressBar
import wget
from pathlib import Path

files_to_download = ["advector_output_rivers_2012.nc", "advector_output_coastal_2012.nc"]

Path("data/").mkdir(exist_ok=True)
for file_to_download in files_to_download:
  if not Path(f"data/{file_to_download}").exists():
    print(f"Downloading {file_to_download}...")
    wget.download(f"https://zenodo.org/record/4740138/files/{file_to_download}", f"data/{file_to_download}")

ds_in = xr.open_dataset("data/advector_output_coastal_2012.nc", chunks="auto")
years_release = ds_in.release_date.dt.year
days_release = ds_in.release_date.dt.dayofyear
arg_release = (years_release - 1993) + days_release / 366

def increasing_sine(x):
    return x + (1 / (2 * np.pi)) * np.sin(2 * np.pi * x + np.pi)

# 1 tonne per particle, as sensible value for a global plastic dispersion model
ds_in["weight"] = 1000 + 1000 * increasing_sine(arg_release)
with ProgressBar():
    ds_in.to_netcdf("data/advector_output_coastal_2012_adapted.nc")

# %%
# Run the Ocean Plastic Assimilator

from src.run_assimilator import run_assimilator
import numpy as np

cell_area = lambda dlon,dlat,lat: dlat * 111 * dlon * 111 * np.cos(lat * np.pi / 180)

GRID_COORDS = (-165, 23, -125, 45)
GRID_RESOLUTION = 0.5

cells_area = np.array([[cell_area(0.5, 0.5, lat_id * GRID_RESOLUTION + GRID_COORDS[1]) for lat_id in range(44)] for lon_id in range(80)])

if __name__ == "__main__":
    run_assimilator(
        particles_dataset_path="data/advector_output_rivers_2012.nc",
        observations_type="from_simulation",
        observations_source_path="data/advector_output_coastal_2012_adapted.nc",
        assimilation_domain_coords=GRID_COORDS,
        assimilation_grid_size=(int(40 / GRID_RESOLUTION), int(22 / GRID_RESOLUTION)),
        size_ensemble=10,
        initial_ensemble_spread=50,
        observations_error_percent=0.01,
        observation_locations=[(25, 12), (50, 24)],
        t_start=0,
        t_end=360,
        initial_mass_multiplicator=1000,
        radius_observation=np.inf,
        simulation_name="self_assimilation_gpgp",
        cells_area=cells_area,
    )
